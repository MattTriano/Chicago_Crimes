# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
# %matplotlib inline

# %%
import geopandas as gpd
import geocoder
import folium
import requests
import time
import math

# %%
# Notebook Styling 
# sns.set()
pd.options.display.max_columns = None
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# The data set below is available on this [City of Chicago Data Portal page](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2), but as the file is approximately 1 GB, I've excluded it from this repo.
#
# [Chicago Community Area Geojson](https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Community-Areas-current-/cauq-8yn6)
#
# [Chicago Police Beat Geojson](https://data.cityofchicago.org/Public-Safety/Boundaries-Police-Beats-current-/aerh-rz74)
#
# [Chicago 2010 Census Block Geojson](https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Census-Blocks-2010/mfzt-js4n)

# %%
def process_chicrimes(chi_crimes):
    chi_crimes['Date'] = pd.to_datetime(chi_crimes['Date'], format='%m/%d/%Y %I:%M:%S %p')
    chi_crimes['Updated On'] = pd.to_datetime(chi_crimes['Updated On'], format='%m/%d/%Y %I:%M:%S %p')
    chi_crimes.drop(['Location', 'X Coordinate', 'Y Coordinate'], axis=1, inplace=True)
    chi_crimes['Block'] = chi_crimes['Block'].astype('category')
    chi_crimes['IUCR'] = chi_crimes['IUCR'].astype('category')
    chi_crimes['Primary Type'] = chi_crimes['Primary Type'].astype('category')
    chi_crimes['Description'] = chi_crimes['Description'].astype('category')
    chi_crimes['Location Description'] = chi_crimes['Primary Type'].astype('category')
    chi_crimes['Beat'] = chi_crimes['Beat'].astype(int)
    chi_crimes['District'] = chi_crimes['District'].astype('category')
    chi_crimes['Ward'] = chi_crimes['Ward'].astype('category')
    chi_crimes['Community Area'] = chi_crimes['Community Area'].astype('category')
    chi_crimes['FBI Code'] = chi_crimes['FBI Code'].astype('category')
    chi_crimes['Hour'] = chi_crimes['Date'].dt.hour
    chi_crimes['Week'] = chi_crimes['Date'].dt.weekofyear
    chi_crimes['Day'] = chi_crimes['Date'].dt.dayofyear
    chi_crimes['Weekday'] = chi_crimes['Date'].dt.dayofweek
    chi_crimes['Month'] = chi_crimes['Date'].dt.month
    chi_crimes['Hour'] = chi_crimes['Hour'].astype('category')
    chi_crimes['Week'] = chi_crimes['Week'].astype('category')
    chi_crimes['Day'] = chi_crimes['Day'].astype('category')
    chi_crimes['Weekday'] = chi_crimes['Weekday'].astype('category')
    chi_crimes['Month'] = chi_crimes['Month'].astype('category')
    return chi_crimes

# %%
CSV_PATH = os.path.join('data', 'big', 'Crimes_-_2001_to_present.csv')
crime_dtypes = {'District':str,
                'Ward':str, 
                'Community Area':str}
chi_crimes = pd.read_csv(CSV_PATH, dtype=crime_dtypes, encoding='latin1') 
chi_crimes.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
#    Domestic  Beat District Ward Community Area FBI Code  X Coordinate  \
# 0     False  1111      011   28             25      04B     1144606.0
# 1     False   725      007   15             67       26     1166468.0
# 2      True   222      002    4             39      08B     1185075.0
# 3     False   225      002    3             40      08B     1178033.0
# 4     False  1113      011   28             25       03     1144920.0
#
#    Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0     1903566.0  2015  02/10/2018 03:50:01 PM  41.891399 -87.744385
# 1     1860715.0  2015  02/10/2018 03:50:01 PM  41.773372 -87.665319
# 2     1875622.0  2015  02/10/2018 03:50:01 PM  41.813861 -87.596643
# 3     1870804.0  2015  02/10/2018 03:50:01 PM  41.800802 -87.622619
# 4     1898709.0  2015  02/10/2018 03:50:01 PM  41.878065 -87.743354
#
#                         Location
# 0  (41.891398861, -87.744384567)
# 1  (41.773371528, -87.665319468)
# 2   (41.81386068, -87.596642837)
# 3  (41.800802415, -87.622619343)
# 4  (41.878064761, -87.743354013)

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6784163 entries, 0 to 6784162
# Data columns (total 22 columns):
# ID                      int64
# Case Number             object
# Date                    object
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                object
# Ward                    object
# Community Area          object
# FBI Code                object
# X Coordinate            float64
# Y Coordinate            float64
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Location                object
# dtypes: bool(2), float64(4), int64(3), object(13)
# memory usage: 1.0+ GB

# %%
chi_crimes = process_chicrimes(chi_crimes)

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6784163 entries, 0 to 6784162
# Data columns (total 24 columns):
# ID                      int64
# Case Number             object
# Date                    datetime64[ns]
# Block                   category
# IUCR                    category
# Primary Type            category
# Description             category
# Location Description    category
# Arrest                  bool
# Domestic                bool
# Beat                    int32
# District                category
# Ward                    category
# Community Area          category
# FBI Code                category
# Year                    int64
# Updated On              datetime64[ns]
# Latitude                float64
# Longitude               float64
# Hour                    category
# Week                    category
# Day                     category
# Weekday                 category
# Month                   category
# dtypes: bool(2), category(14), datetime64[ns](2), float64(2), int32(1), int64(2), object(1)
# memory usage: 533.6+ MB

# %%
query = chi_crimes.loc[:,'Primary Type'].value_counts()
query
# Out:
# THEFT                                1427332
# BATTERY                              1238778
# CRIMINAL DAMAGE                       775204
# NARCOTICS                             712700
# ASSAULT                               421167
# OTHER OFFENSE                         420879
# BURGLARY                              389632
# MOTOR VEHICLE THEFT                   315719
# DECEPTIVE PRACTICE                    265288
# ROBBERY                               257023
# CRIMINAL TRESPASS                     194278
# WEAPONS VIOLATION                      71444
# PROSTITUTION                           68418
# PUBLIC PEACE VIOLATION                 47988
# OFFENSE INVOLVING CHILDREN             45677
# CRIM SEXUAL ASSAULT                    27348
# SEX OFFENSE                            25235
# INTERFERENCE WITH PUBLIC OFFICER       15309
# GAMBLING                               14427
# LIQUOR LAW VIOLATION                   14082
# ARSON                                  11202
# HOMICIDE                                9505
# KIDNAPPING                              6690
# INTIMIDATION                            3960
# STALKING                                3404
# OBSCENITY                                589
# CONCEALED CARRY LICENSE VIOLATION        304
# NON-CRIMINAL                             171
# PUBLIC INDECENCY                         164
# OTHER NARCOTIC VIOLATION                 124
# HUMAN TRAFFICKING                         51
# NON - CRIMINAL                            38
# RITUALISM                                 23
# NON-CRIMINAL (SUBJECT SPECIFIED)           9
# DOMESTIC VIOLENCE                          1
# Name: Primary Type, dtype: int64

# %%
chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE', 'Description'].unique()
# Out:
# [FIRST DEGREE MURDER, RECKLESS HOMICIDE, INVOLUNTARY MANSLAUGHTER]
# Categories (3, object): [FIRST DEGREE MURDER, RECKLESS HOMICIDE, INVOLUNTARY MANSLAUGHTER]

# %%
def plot_monthly_and_yearly_rates(df, crime, max_year=2018, figsize=(12,4)):
    with sns.axes_style("darkgrid"):
        df = df[df['Year'] <= max_year]
        df.set_index('Date', inplace=True)
        
        fig, ax = plt.subplots(sharex=True, figsize=figsize)
        mo_df = df[['ID']].groupby([df.index.year, df.index.month]).count()
        mo_df.plot(ax=ax, kind='line', legend=None)
        ax.set_title('Monthly (top) and Annual (bot) {} in Chicago'.format(crime), fontsize=16)
        ax.set_ylabel('{} per Month'.format(crime), fontsize=14)
        ax.set_xlabel('', fontsize=14)
        ax.set_ylim([0, mo_df['ID'].max() * 1.1])
        plt.tight_layout()
        
        fig, ax = plt.subplots(sharex=True, figsize=(12,4))
        yr_df = df[['ID']].groupby([df.index.year]).count()
        yr_df.plot(ax=ax, legend=None)
        ax.set_ylabel('{} per Year'.format(crime), fontsize=14)
        ax.set_xlabel('Year', fontsize=16)
        ax.set_ylim([0, yr_df['ID'].max() * 1.1])
        plt.tight_layout()
        
        return df

# %%
homicides = plot_monthly_and_yearly_rates(chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE'].copy(), 'Homicides')

# %% [markdown]
# ### Homicide Counts per year (Unique IDs)

# %%
hom_counts = homicides[['ID']].groupby([homicides.index.year]).count()
hom_counts.rename({'ID':'Annual_Homs'}, axis=1, inplace=True)
hom_counts
# Out:
#       Annual_Homs
# Date
# 2001          667
# 2002          657
# 2003          604
# 2004          454
# 2005          453
# 2006          476
# 2007          447
# 2008          513
# 2009          460
# 2010          438
# 2011          438
# 2012          506
# 2013          422
# 2014          426
# 2015          502
# 2016          786
# 2017          674
# 2018          580

# %% [markdown]
# ## Non-Fatal Shootings

# %% [markdown]
# Per the [CPD Incident Reporting Guide](http://directives.chicagopolice.org/forms/CPD-63.451_Table.pdf), IUCR (Illinois Uniform Crime Reporting) numbers relating to shootings are:
# * 041A (shot victim with handgun)
# * 041B (shot victim armed with non-handgun firearm)
# * 0450 (shot police officer with a handgun)
# * 0451 (shot police officer armed with non-handgun firearm)
# * 0480 (shot protected employee with handgun)
# * 0481 (shot protected employee armed with non-handgun firearm)
# * 0488 (shot family or household member with handgun)
# * 0489 (shot family or household member with non-handgun firearm)
# * 0490 (Ritual mutilation with a handgun)
# * 0491 (Ritual mutilation with a non-handgun firearm)
#
# Additionally, we know that crimes with these codings weren't fatal, as they would have been upgraded to homicides if they were fatal.

# %%
non_fatal_shootings = chi_crimes[(chi_crimes['IUCR'].isin(['041A','041B','0450','0451','0480','0481','0488','0489']))].copy()
non_fatal_shootings.head()
# Out:
#            ID Case Number                Date                      Block  \
# 0    10000092    HY189866 2015-03-18 19:44:00            047XX W OHIO ST
# 29   10000130    HY190003 2015-03-18 21:59:00       086XX S CARPENTER ST
# 48   10000159    HY190043 2015-03-18 23:00:00        057XX N KENMORE AVE
# 72   10000197    HY190067 2015-03-18 23:20:00        046XX S INDIANA AVE
# 792  10001730    HY191339 2015-03-20 00:25:00  062XX S COTTAGE GROVE AVE
#
#      IUCR Primary Type          Description Location Description  Arrest  \
# 0    041A      BATTERY  AGGRAVATED: HANDGUN              BATTERY   False
# 29   041A      BATTERY  AGGRAVATED: HANDGUN              BATTERY   False
# 48   041A      BATTERY  AGGRAVATED: HANDGUN              BATTERY   False
# 72   041A      BATTERY  AGGRAVATED: HANDGUN              BATTERY   False
# 792  041A      BATTERY  AGGRAVATED: HANDGUN              BATTERY   False
#
#      Domestic  Beat District Ward Community Area FBI Code  Year  \
# 0       False  1111      011   28             25      04B  2015
# 29      False   613      006   21             71      04B  2015
# 48      False  2022      020   48             77      04B  2015
# 72      False   215      002    3             38      04B  2015
# 792     False   313      003   20             42      04B  2015
#
#              Updated On   Latitude  Longitude Hour Week Day Weekday Month
# 0   2018-02-10 15:50:01  41.891399 -87.744385   19   12  77       2     3
# 29  2018-02-10 15:50:01  41.737129 -87.649728   21   12  77       2     3
# 48  2018-02-10 15:50:01  41.986392 -87.656701   23   12  77       2     3
# 72  2018-02-10 15:50:01  41.810671 -87.621248   23   12  77       2     3
# 792 2018-02-10 15:50:01  41.781499 -87.605956    0   12  79       4     3

# %%
non_fatal_shootings = plot_monthly_and_yearly_rates(chi_crimes[(chi_crimes['IUCR'].isin(['041A','041B','0450','0451','0480','0481','0488','0489']))].copy(), 'Non-Fatal Shootings')

# %% [markdown]
# ### Non-Fatal Shootings per Year (Unique IDs)

# %%
nfs_counts = non_fatal_shootings[['ID']].groupby([non_fatal_shootings.index.year]).count()
nfs_counts.rename({'ID':'Annual_Non_Fatal_Shootings'}, axis=1, inplace=True)
nfs_counts
# Out:
#       Annual_Non_Fatal_Shootings
# Date
# 2001                        4175
# 2002                        3919
# 2003                        2991
# 2004                        1781
# 2005                        1703
# 2006                        1785
# 2007                        1730
# 2008                        1996
# 2009                        1812
# 2010                        1857
# 2011                        1738
# 2012                        1889
# 2013                        1403
# 2014                        1606
# 2015                        1900
# 2016                        2720
# 2017                        2079
# 2018                        1835

# %%
query = chi_crimes['Description'].value_counts()
query[(query > 10000) & (query < 50000)]
# Out:
# UNLAWFUL POSS OF HANDGUN                           47548
# SOLICIT ON PUBLIC WAY                              47349
# FINANCIAL ID THEFT: OVER $300                      44531
# OTHER VEHICLE OFFENSE                              36500
# TO STATE SUP LAND                                  36336
# VIOLATE ORDER OF PROTECTION                        33754
# CRIMINAL DEFACEMENT                                33727
# POCKET-PICKING                                     33496
# FRAUD OR CONFIDENCE GAME                           32551
# ILLEGAL USE CASH CARD                              32153
# THEFT OF LABOR/SERVICES                            31319
# PRO EMP HANDS NO/MIN INJURY                        29623
# RECKLESS CONDUCT                                   28888
# SOLICIT NARCOTICS ON PUBLICWAY                     27047
# FINANCIAL IDENTITY THEFT OVER $ 300                25575
# TO RESIDENCE                                       25005
# MANU/DELIVER: HEROIN (WHITE)                       24969
# POSS: COCAINE                                      24788
# TRUCK, BUS, MOTOR HOME                             24597
# MANU/DELIVER:CRACK                                 24340
# HARASSMENT BY ELECTRONIC MEANS                     24310
# THEFT/RECOVERY: AUTOMOBILE                         22652
# ATTEMPT POSSESSION NARCOTICS                       21282
# FALSE/STOLEN/ALTERED TRP                           20807
# AGG PO HANDS NO/MIN INJURY                         19504
# AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON     18382
# POSS: CANNABIS MORE THAN 30GMS                     17859
# FORGERY                                            17391
# ATTEMPT FORCIBLE ENTRY                             17107
# PURSE-SNATCHING                                    16757
# FOUND SUSPECT NARCOTICS                            16626
# AGGRAVATED                                         15269
# NON-AGGRAVATED                                     15231
# FINANCIAL ID THEFT:$300 &UNDER                     15206
# SOLICIT FOR BUSINESS                               14698
# BOGUS CHECK                                        14506
# CHILD ABUSE                                        13744
# TO CITY OF CHICAGO PROPERTY                        13275
# ARMED: OTHER DANGEROUS WEAPON                      12663
# AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST    12640
# COUNTERFEITING DOCUMENT                            12148
# GAME/DICE                                          12122
# ARMED:KNIFE/CUTTING INSTRUMENT                     11886
# OTHER CRIME INVOLVING PROPERTY                     11556
# ATT: AUTOMOBILE                                    11425
# MANU/DEL:CANNABIS 10GM OR LESS                     11349
# ATTEMPT THEFT                                      11231
# MANU/DEL:CANNABIS OVER 10 GMS                      11128
# Name: Description, dtype: int64

# %%
# X and Y labels
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
weeks = np.arange(0,53).tolist()
weekdays = ['Sun', 'Sat', 'Fri', 'Thu', 'Wed', 'Tue', 'Mon']
hours = np.arange(23,-1,-1).tolist()

year = 2003
y_ax = 'Hour'
x_ax = 'Month'
x_labs = months
crime_desc = 'DOMESTIC BATTERY SIMPLE'
def plot_crime_freq_heatmap(crime_desc, x_ax, y_ax, x_labs, y_labs, year, df=chi_crimes, figsize=(14,6), cmap='coolwarm'):
    tmp = df[(df['Description'] == crime_desc) &
                     (df['Year'] == year)][['Description', y_ax, x_ax]] 
    tmp1 = tmp.pivot_table(index=y_ax, columns=x_ax, values='Description', aggfunc=['count'])
    tmp1.sort_index(ascending=False, inplace=True)
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(tmp1, ax=ax, annot=False, fmt='d', cmap=cmap)
    ax.xaxis.set_ticklabels(x_labs, fontsize=14)
    ax.yaxis.set_ticklabels(y_labs, fontsize=12, rotation=0)
    ax.set_xlabel(x_ax, fontsize=14)
    ax.set_ylabel(y_ax, fontsize=14)
    ax.set_title('Frequency of crime: "{}" by {} and {} for {}'
                 .format(crime_desc, y_ax, x_ax, year), fontsize=16)
    plt.show()
    
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('POSS: CRACK', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('POSS: CRACK', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Week', 'Weekday', weeks, weekdays, 2006, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Month', 'Hour', months, hours, 2010)

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Week', 'Weekday', weeks, weekdays, 2010)

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Month', 'Hour', months, hours, 2010)

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Week', 'Weekday', weeks, weekdays, 2010)

# %%
query = chi_crimes['Description'].value_counts()
query[(query > 5000) & (query < 10000)]
# Out:
# ATTEMPT: STRONGARM-NO WEAPON               9888
# FIRST DEGREE MURDER                        9466
# AGGRAVATED VEHICULAR HIJACKING             9464
# CRIMINAL SEXUAL ABUSE                      9109
# OTHER OFFENSE                              9012
# POSSESSION OF DRUG EQUIPMENT               8791
# THEFT OF LOST/MISLAID PROP                 8514
# UNLAWFUL USE OTHER DANG WEAPON             8481
# ATTEMPT: ARMED-HANDGUN                     8311
# FINANCIAL IDENTITY THEFT $300 AND UNDER    7696
# COUNTERFEIT CHECK                          7598
# VEHICLE TITLE/REG OFFENSE                  7563
# OTHER WEAPONS VIOLATION                    7351
# BY FIRE                                    7301
# PUBLIC INDECENCY                           7291
# LICENSE VIOLATION                          6975
# OTHER CRIME AGAINST PERSON                 6955
# ENDANGERING LIFE/HEALTH CHILD              6689
# BOMB THREAT                                6565
# TO STATE SUP PROP                          5763
# RESIST/OBSTRUCT/DISARM OFFICER             5758
# AGG CRIMINAL SEXUAL ABUSE                  5595
# OBSTRUCTING IDENTIFICATION                 5378
# PAROLE VIOLATION                           5263
# HOME INVASION                              5098
# VEHICULAR HIJACKING                        5080
# CYCLE, SCOOTER, BIKE W-VIN                 5043
# Name: Description, dtype: int64

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Month', 'Weekday', months, weekdays, 2016)

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Month', 'Hour', months, hours, 2016)

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Week', 'Hour', weeks, hours, 2016, figsize=(14,5))

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Week', 'Weekday', weeks, weekdays, 2016)

# %%
ZIP_SHP_PATH = os.path.join('zip://', 'data', 'Boundaries - Police Beats (current).zip')
beats = gpd.read_file(ZIP_SHP_PATH)
beats['beat_num'] = beats['beat_num'].astype(int)
ax = beats.plot(figsize=(10,10))
ax.grid('off')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsizip/data\Boundaries - Police Beats (current).zip' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-38-cd50bf4ee587> in <module>()
#       1 ZIP_SHP_PATH = os.path.join('zip://', 'data', 'Boundaries - Police Beats (current).zip')
# ----> 2 beats = gpd.read_file(ZIP_SHP_PATH)
#       3 beats['beat_num'] = beats['beat_num'].astype(int)
#       4 ax = beats.plot(figsize=(10,10))
#       5 ax.grid('off')
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      63         reader = fiona.open
#      64
# ---> 65     with reader(path_or_bytes, **kwargs) as features:
#      66         crs = features.crs
#      67         if bbox is not None:
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     403             with Env.from_defaults(session=session):
#     404                 log.debug("Credentialized: {!r}".format(getenv()))
# --> 405                 return f(*args, **kwargs)
#     406     return wrapper
#     407
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: '/vsizip/data\Boundaries - Police Beats (current).zip' does not exist in the file system, and is not recognized as a supported dataset name.

# %%
def map_counts(df_, col_val, start_date='2001-01-01', end_date='2019-01-03', gdf=beats, val='Arrest', col='Primary Type', my_cmap='YlGn', scale=0.6, tight=True, figsize=(10,10)):
    df = df_[(df_['Date'] >= start_date) & (df_['Date'] <= end_date)].copy()
    fig, ax = plt.subplots(figsize=figsize)
    counts = df.pivot_table(index='Beat', values=val, columns=col, aggfunc='count', fill_value=0)[[col_val]]
    map_df = pd.merge(left=gdf, right=counts, right_index=True, left_on='beat_num')
    vmin = map_df[col_val].min()
    vmax = map_df[col_val].max()
    
    base = gdf.plot(figsize=figsize, color='white', edgecolor='black', linewidth=2, ax=ax)
    map_df.plot(column=col_val, ax=base, cmap=my_cmap)
    _ = ax.axis('off')
    _ = ax.set_title('Counts of {} per police beat\nfrom {} to {}'.format(col_val, start_date, end_date),
                     fontdict={'fontsize': '25', 'fontweight':'3'})
    
    sm = plt.cm.ScalarMappable(cmap=my_cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm._A = []
    cbar = fig.colorbar(sm, shrink=scale)
    if tight:
        plt.tight_layout()

# %%
chi_crimes['Primary Type'].value_counts()

# %%
map_counts(chi_crimes, 'THEFT', '2012-01-01', '2012-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'THEFT', '2001-01-01', '2009-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'CRIM SEXUAL ASSAULT', '2010-01-01', '2018-12-31', scale=0.6, figsize=(10,10))

# %% [markdown]
# That's pretty wild. I'm not sure why the magnificent mile is such an outlier regarding criminal sexual assault. Let's take a closer look.

# %%
map_counts(chi_crimes[chi_crimes['Beat'] == 1834], 'CRIM SEXUAL ASSAULT', gdf=beats[beats['beat_num'] == 1834], 
           start_date='2010-01-01', end_date='2018-12-31', scale=0.2)

# %%
query = chi_crimes.loc[(chi_crimes['Beat'] == 1834) & (chi_crimes['Primary Type'] == 'CRIM SEXUAL ASSAULT'), 'IUCR'].value_counts()
query[query > 0]
# Out:
# 0281    182
# 0265     15
# 0291      7
# 0261      5
# 0264      2
# 0273      2
# 0266      2
# 0263      1
# Name: IUCR, dtype: int64

# %%
chi_crimes[chi_crimes['Primary Type'] == 'CRIM SEXUAL ASSAULT']['IUCR'].value_counts()
# Out:
# 0281    15231
# 0265     4460
# 0266     2709
# 0261     1697
# 0291     1246
# 0263     1049
# 0264      305
# 0275      247
# 0273      172
# 0271      147
# 0274       49
# 0262       33
# 0272        3
# 1153        0
# 1155        0
# 1156        0
# 1160        0
# 1154        0
# 9901        0
# 1152        0
# 1185        0
# 1151        0
# 1150        0
# 1170        0
# 1230        0
# 1195        0
# 1200        0
# 1205        0
# 1206        0
# 1210        0
#         ...
# 2080        0
# 2090        0
# 2091        0
# 2092        0
# 2021        0
# 2019        0
# 1754        0
# 2018        0
# 1755        0
# 1780        0
# 1790        0
# 1791        0
# 1792        0
# 1811        0
# 1812        0
# 1821        0
# 1822        0
# 1840        0
# 1850        0
# 1860        0
# 1900        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# 2014        0
# 2015        0
# 2016        0
# 2017        0
# 0110        0
# Name: IUCR, Length: 401, dtype: int64

# %%
map_counts(chi_crimes, 'NARCOTICS', '2012-01-01', '2014-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'PROSTITUTION', '2012-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'HOMICIDE', '2012-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'BATTERY', '2014-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
fig, ax = plt.subplots(figsize=(12,6))
tmp = chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE'].copy()
tmp.set_index('Date', inplace=True)
tmp[['ID']].groupby([tmp.index.year]).count().plot(ax=ax, legend=None)
# plt.show()
# tmp.index.year

# %%
tmp = chi_crimes.loc[chi_crimes['Primary Type'] == 'BATTERY'].copy()
query = tmp.loc[:,'Description'].value_counts()
query[query > 0]
# Out:
# DOMESTIC BATTERY SIMPLE                                        520593
# SIMPLE                                                         504882
# AGGRAVATED: OTHER DANG WEAPON                                   68182
# AGGRAVATED: HANDGUN                                             36622
# AGGRAVATED:KNIFE/CUTTING INSTR                                  27045
# AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON                  18382
# PRO EMP HANDS NO/MIN INJURY                                     15226
# AGG PO HANDS NO/MIN INJURY                                      13203
# AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST                 12640
# AGG: HANDS/FIST/FEET NO/MINOR INJURY                             4958
# AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY      3576
# AGG: HANDS/FIST/FEET SERIOUS INJURY                              2335
# AGGRAVATED OF A SENIOR CITIZEN                                   2231
# AGGRAVATED PO: OTHER DANG WEAP                                   1555
# AGGRAVATED DOMESTIC BATTERY                                      1546
# AGG PRO.EMP: OTHER DANG WEAPON                                   1364
# AGGRAVATED: OTHER FIREARM                                        1327
# AGGRAVATED OF A CHILD                                             670
# AGG PRO EMP HANDS SERIOUS INJ                                     466
# AGG PO HANDS ETC SERIOUS INJ                                      461
# AGGRAVATED DOMESTIC BATTERY: HANDGUN                              356
# AGGRAVATED PO: HANDGUN                                            306
# AGGRAVATED PO: KNIFE/CUT INSTR                                    221
# AGG PRO.EMP:KNIFE/CUTTING INST                                    180
# AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM                        136
# AGG PRO.EMP: HANDGUN                                              128
# OF UNBORN CHILD                                                    80
# AGGRAVATED OF A UNBORN CHILD                                       51
# AGG PRO.EMP: OTHER FIREARM                                         29
# AGGRAVATED PO: OTHER FIREARM                                       27
# Name: Description, dtype: int64

# %%
class GeoSessions:
    def __init__(self):
        self.Arcgis = requests.Session()
        self.Komoot = requests.Session()
        self.USCensus = requests.Session()
        self.OSM = requests.Session()

def create_sessions():
    return GeoSessions()

def geocode_address(address, s):
    g = geocoder.arcgis(address, session=s.Arcgis)
    if (g.ok == False):
        g = geocoder.komoot(address, session=s.Komoot)
    if (g.ok == False):
        g = geocoder.osm(address, session=s.OSM)        
    if (g.ok == False):
        g = geocoder.uscensus(address, session=s.USCensus)
    return g

# %% [markdown]
# ## Missing Latitude and Longitude Values
#
# As the printouts below show, there are 59445 pairs of Latitude and Longitude values that are missing. While it's a small portion of the total data set, I can't know if it's missing at random (MAR) or missing completely at random (MCAR), so leaving it out might bias the data set. As I can programatically geocode the missing values, this is a solveable problem.

# %%
missing_lats = chi_crimes['Latitude'].isnull()
missing_lons = chi_crimes['Longitude'].isnull()
missing_addrs = chi_crimes['Block'].isnull()
print('Number of missing latitude values: {}'.format(missing_lats.sum()))
print('Number of missing longitude values: {}'.format(missing_lons.sum()))
print('Number of missing Address values: {}'.format(missing_addrs.sum()))
print('Number of rows missing both lat and lon values: {}'
      .format(np.array(missing_lats[missing_lats] == missing_lons[missing_lons]).sum()))
# Out:
# Number of missing latitude values: 59445
# Number of missing longitude values: 59445
# Number of missing Address values: 0
# Number of rows missing both lat and lon values: 59445

# %%
addrs_df = chi_crimes[missing_lats][['Block']]
addrs_df['Address'] = [x.replace('XX', '00') for x in addrs_df['Block']]
addrs_df['Address'] = [x.replace('0X ', '00 ') for x in addrs_df['Address']]
addrs_df['Address'] = addrs_df['Address'] + ', Chicago, IL'
addrs_df['Latitude'] = np.nan
addrs_df['Longitude'] = np.nan
addrs_df.head()
# Out:
#                       Block                             Address  Latitude  \
# 21          0000X E LAKE ST        00000 E LAKE ST, Chicago, IL       NaN
# 125   077XX S GREENWOOD AVE  07700 S GREENWOOD AVE, Chicago, IL       NaN
# 1325     074XX N ROGERS AVE     07400 N ROGERS AVE, Chicago, IL       NaN
# 1539      077XX S ESSEX AVE      07700 S ESSEX AVE, Chicago, IL       NaN
# 1603  111XX S VINCENNES AVE  11100 S VINCENNES AVE, Chicago, IL       NaN
#
#       Longitude
# 21          NaN
# 125         NaN
# 1325        NaN
# 1539        NaN
# 1603        NaN

# %%
addrs_df = addrs_df.drop_duplicates('Address', keep='first').copy()
addrs_df.shape
# Out:
# (21350, 4)

# %%
# addrs_df = pd.merge(left=latlon_df, 
#                     right=pd.DataFrame(latlon_df['Address'].unique(), columns=['Address']),
#                     how='left', left_on='Block', right_on='Address')
# addrs_df.drop('Address_y', axis=1, inplace=True)
# addrs_df.columns = ['Block', 'Address'] 
# addrs_df['Latitude'] = np.nan
# addrs_df['Longitude'] = np.nan
# addrs_df.head()
# Out:
#                    Block                             Address  Latitude  \
# 0        0000X E LAKE ST        00000 E LAKE ST, Chicago, IL       NaN
# 1  077XX S GREENWOOD AVE  07700 S GREENWOOD AVE, Chicago, IL       NaN
# 2     074XX N ROGERS AVE     07400 N ROGERS AVE, Chicago, IL       NaN
# 3      077XX S ESSEX AVE      07700 S ESSEX AVE, Chicago, IL       NaN
# 4  111XX S VINCENNES AVE  11100 S VINCENNES AVE, Chicago, IL       NaN
#
#    Longitude
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
addrs_df[(addrs_df['Latitude'].isnull())]['Address'].unique()
# Out:
# array(['00000 E LAKE ST, Chicago, IL',
#        '07700 S GREENWOOD AVE, Chicago, IL',
#        '07400 N ROGERS AVE, Chicago, IL', ...,
#        '11800 S WENTWORTH AVE, Chicago, IL',
#        '06200 N PAULINA ST, Chicago, IL',
#        '04900 N KILDARE AVE, Chicago, IL'], dtype=object)

# %%
OUT_PATH = os.path.join('data', 'geocoded_chi_crimes.csv')
if os.path.isfile(OUT_PATH):
    addrs_df = pd.read_csv(OUT_PATH)
    print('It existed')
addrs_df.head()
# Out:
# It existed
#                    Block                             Address   Latitude  \
# 0        0000X E LAKE ST        00000 E LAKE ST, Chicago, IL  41.900947
# 1  077XX S GREENWOOD AVE  07700 S GREENWOOD AVE, Chicago, IL  41.810638
# 2     074XX N ROGERS AVE     07400 N ROGERS AVE, Chicago, IL  42.019914
# 3      077XX S ESSEX AVE      07700 S ESSEX AVE, Chicago, IL  42.315241
# 4  111XX S VINCENNES AVE  11100 S VINCENNES AVE, Chicago, IL  41.507930
#
#    Longitude
# 0 -87.620411
# 1 -87.599286
# 2 -87.667048
# 3 -87.858772
# 4 -87.640085

# %%
s = create_sessions()

# %%
addr = addrs_df['Address'][0]
tmp = geocoder.osm(addr, session=s.OSM)
print(addr)
print('Latitude:  {}'.format(tmp.lat))
print('Longitude: {}'.format(tmp.lng))
# Out:
# 00000 E LAKE ST, Chicago, IL
# Latitude:  41.8857868
# Longitude: -87.6225308

# %%
addr = addrs_df['Address'][0]
tmp = geocoder.komoot(addr, session=s.Komoot)
print(addr)
print('Latitude:  {}'.format(tmp.lat))
print('Longitude: {}'.format(tmp.lng))
# Out:
# 00000 E LAKE ST, Chicago, IL
# Latitude:  41.9009473
# Longitude: -87.6204114

# %%
failed_inds = []
iterations_between_saves = 100

# %%
addrs_df[addrs_df['Latitude'].isnull()][:2501].index.tolist()
# Out:
# []

# %%
missing_latlong_indices = addrs_df[addrs_df['Latitude'].isnull()][:2501].index.tolist()

for i in missing_latlong_indices:
    try:
        if i%iterations_between_saves == 0:
            print('reached index {}, saving df'.format(i))
            addrs_df.to_csv(OUT_PATH, index=False)
        addr = addrs_df['Address'][i]
        tmp = geocode_address(addr, s)
        addrs_df.loc[i,'Latitude'] = tmp.lat
        addrs_df.loc[i,'Longitude'] = tmp.lng
    except Exception as e:
        failed_inds.append(i)
addrs_df.to_csv(OUT_PATH, index=False)
# Out:
# reached index 48500, saving df
# reached index 48700, saving df
# reached index 49500, saving df
# reached index 50700, saving df
# reached index 52100, saving df
# reached index 52300, saving df
# reached index 52800, saving df
# reached index 53400, saving df
# reached index 54400, saving df
# reached index 55400, saving df
# reached index 56700, saving df
# reached index 57100, saving df
# reached index 57600, saving df
# reached index 57700, saving df
# reached index 57800, saving df
# reached index 58400, saving df
# reached index 58500, saving df
# reached index 58900, saving df

# %%
# How many rows are missing Latitude values?
addrs_df['Latitude'].isnull().sum()
# Out:
# 0

# %%
# how many indices failed to geocode?
failed_inds
# Out:
# []

# %%
chi_crimes['Latitude'].isnull().sum()
# Out:
# 59445

# %%
addrs_df.head()
# Out:
#                    Block                             Address   Latitude  \
# 0        0000X E LAKE ST        00000 E LAKE ST, Chicago, IL  41.900947
# 1  077XX S GREENWOOD AVE  07700 S GREENWOOD AVE, Chicago, IL  41.810638
# 2     074XX N ROGERS AVE     07400 N ROGERS AVE, Chicago, IL  42.019914
# 3      077XX S ESSEX AVE      07700 S ESSEX AVE, Chicago, IL  42.315241
# 4  111XX S VINCENNES AVE  11100 S VINCENNES AVE, Chicago, IL  41.507930
#
#    Longitude
# 0 -87.620411
# 1 -87.599286
# 2 -87.667048
# 3 -87.858772
# 4 -87.640085

# %%
addrs_df.drop('Address', axis=1, inplace=True)
addrs_df.head()
# Out:
#                    Block   Latitude  Longitude
# 0        0000X E LAKE ST  41.900947 -87.620411
# 1  077XX S GREENWOOD AVE  41.810638 -87.599286
# 2     074XX N ROGERS AVE  42.019914 -87.667048
# 3      077XX S ESSEX AVE  42.315241 -87.858772
# 4  111XX S VINCENNES AVE  41.507930 -87.640085

# %%
tmp = chi_crimes[['Block', 'Latitude', 'Longitude']]
tmp1 = pd.merge(left=tmp, right=addrs_df, on='Block', how='left')
tmp1['Latitude'] = tmp1['Latitude_x'].copy()
tmp1['Longitude'] = tmp1['Longitude_x'].copy()
tmp1.loc[tmp1['Latitude'].isnull(), 'Latitude'] = tmp1[tmp1['Latitude'].isnull()]['Latitude_y'].copy()
tmp1.loc[tmp1['Longitude'].isnull(), 'Longitude'] = tmp1[tmp1['Longitude'].isnull()]['Longitude_y'].copy()
tmp1.drop(['Latitude_x', 'Latitude_y', 'Longitude_x', 'Longitude_y'], axis=1, inplace=True)

# %%
tmp1['Latitude'].isnull().sum()
# Out:
# 0

# %%
tmp1['Longitude'].isnull().sum()
# Out:
# 0

# %%
tmp1.head()
# Out:
#                     Block   Latitude  Longitude
# 0         047XX W OHIO ST  41.891399 -87.744385
# 1  066XX S MARSHFIELD AVE  41.773372 -87.665319
# 2   044XX S LAKE PARK AVE  41.813861 -87.596643
# 3    051XX S MICHIGAN AVE  41.800802 -87.622619
# 4        047XX W ADAMS ST  41.878065 -87.743354

# %%
tmp1.shape
# Out:
# (6673140, 3)

# %%
tmp = pd.merge(left=chi_crimes, right=addrs_df, how='left', on='Block')
tmp
# Out:
#                ID                Date                                Block  \
# 0        10000092 2015-03-18 19:44:00                      047XX W OHIO ST
# 1        10000094 2015-03-18 23:00:00               066XX S MARSHFIELD AVE
# 2        10000095 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 3        10000096 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 4        10000097 2015-03-18 21:00:00                     047XX W ADAMS ST
# 5        10000098 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 6        10000099 2015-03-18 23:00:00                    070XX S MORGAN ST
# 6673129  11413277 2018-07-13 20:00:00                     005XX W OHARE ST
# 6673130  11413336 2018-07-15 15:00:00                     006XX E 102ND PL
# 6673131  11413341 2018-08-05 07:00:00                118XX S WENTWORTH AVE
# 6673132  11413342 2018-07-30 17:20:00                    132XX S ELLIS AVE
# 6673133  11413356 2018-08-07 12:00:00                   062XX N PAULINA ST
# 6673134  11413365 2018-06-22 11:00:00                  049XX N KILDARE AVE
# 6673135  11413384 2018-08-03 17:30:00               092XX S COMMERCIAL AVE
# 6673136  11413387 2018-08-01 00:00:00                     002XX W 108TH ST
# 6673137  11413394 2018-08-02 21:00:00                      016XX E 78TH ST
# 6673138  11413407 2018-08-05 09:57:00                   079XX S CICERO AVE
# 6673139  11413411 2018-08-07 12:31:00                 008XX N MICHIGAN AVE
#
#          IUCR                Primary Type  \
# 0        041A                     BATTERY
# 1        4625               OTHER OFFENSE
# 2        0486                     BATTERY
# 3        0460                     BATTERY
# 4        031A                     ROBBERY
# 5        0460                     BATTERY
# 6        0486                     BATTERY
# 7        0486                     BATTERY
# 8        1811                   NARCOTICS
# 9        0460                     BATTERY
# 10       1320             CRIMINAL DAMAGE
# 11       2825               OTHER OFFENSE
# 12       143A           WEAPONS VIOLATION
# 13       0460                     BATTERY
# 14       0860                       THEFT
# 15       0610                    BURGLARY
# 16       0910         MOTOR VEHICLE THEFT
# 17       0890                       THEFT
# 18       0470      PUBLIC PEACE VIOLATION
# 19       0890                       THEFT
# 20       0860                       THEFT
# 21       1140          DECEPTIVE PRACTICE
# 22       0320                     ROBBERY
# 23       0430                     BATTERY
# 24       141A           WEAPONS VIOLATION
# 25       0486                     BATTERY
# 26       0486                     BATTERY
# 27       0560                     ASSAULT
# 28       0460                     BATTERY
# 29       041A                     BATTERY
# ...       ...                         ...
# 6673110  1754  OFFENSE INVOLVING CHILDREN
# 6673111  1153          DECEPTIVE PRACTICE
# 6673112  0610                    BURGLARY
# 6673113  1135          DECEPTIVE PRACTICE
# 6673114  1752  OFFENSE INVOLVING CHILDREN
# 6673115  1110          DECEPTIVE PRACTICE
# 6673116  0810                       THEFT
# 6673117  1153          DECEPTIVE PRACTICE
# 6673118  0860                       THEFT
# 6673119  0860                       THEFT
# 6673120  1153          DECEPTIVE PRACTICE
# 6673121  0610                    BURGLARY
# 6673122  0420                     BATTERY
# 6673123  0890                       THEFT
# 6673124  1200          DECEPTIVE PRACTICE
# 6673125  1310             CRIMINAL DAMAGE
# 6673126  2826               OTHER OFFENSE
# 6673127  0486                     BATTERY
# 6673128  0820                       THEFT
# 6673129  0910         MOTOR VEHICLE THEFT
# 6673130  1130          DECEPTIVE PRACTICE
# 6673131  1153          DECEPTIVE PRACTICE
# 6673132  0560                     ASSAULT
# 6673133  0820                       THEFT
# 6673134  0820                       THEFT
# 6673135  0910         MOTOR VEHICLE THEFT
# 6673136  1310             CRIMINAL DAMAGE
# 6673137  0820                       THEFT
# 6673138  0860                       THEFT
# 6673139  0860                       THEFT
#
#                                  Description            Location Description  \
# 0                        AGGRAVATED: HANDGUN                          STREET
# 1                           PAROLE VIOLATION                          STREET
# 2                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 3                                     SIMPLE                       APARTMENT
# 4                             ARMED: HANDGUN                        SIDEWALK
# 5                                     SIMPLE                       APARTMENT
# 6                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 7                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 8               POSS: CANNABIS 30GMS OR LESS                          STREET
# 9                                     SIMPLE         RESIDENCE PORCH/HALLWAY
# 10                                TO VEHICLE  PARKING LOT/GARAGE(NON.RESID.)
# 11                   HARASSMENT BY TELEPHONE     CTA GARAGE / OTHER PROPERTY
# 12                  UNLAWFUL POSS OF HANDGUN          DRIVEWAY - RESIDENTIAL
# 13                                    SIMPLE                        SIDEWALK
# 14                              RETAIL THEFT                     GAS STATION
# 15                            FORCIBLE ENTRY                       APARTMENT
# 16                                AUTOMOBILE                           OTHER
# 17                             FROM BUILDING              GROCERY FOOD STORE
# 18                          RECKLESS CONDUCT                           ALLEY
# 19                             FROM BUILDING                   BAR OR TAVERN
# 20                              RETAIL THEFT              GROCERY FOOD STORE
# 21                              EMBEZZLEMENT                           OTHER
# 22                     STRONGARM - NO WEAPON                           OTHER
# 23             AGGRAVATED: OTHER DANG WEAPON                       APARTMENT
# 24                      UNLAWFUL USE HANDGUN          VEHICLE NON-COMMERCIAL
# 25                   DOMESTIC BATTERY SIMPLE                       APARTMENT
# 26                   DOMESTIC BATTERY SIMPLE                       APARTMENT
# 27                                    SIMPLE                       RESIDENCE
# 28                                    SIMPLE                       APARTMENT
# 29                       AGGRAVATED: HANDGUN         RESIDENCE PORCH/HALLWAY
# ...                                      ...                             ...
# 6673110       AGG SEX ASSLT OF CHILD FAM MBR                       APARTMENT
# 6673111  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673112                       FORCIBLE ENTRY                       RESIDENCE
# 6673113                      INSURANCE FRAUD                       RESIDENCE
# 6673114        AGG CRIM SEX ABUSE FAM MEMBER                       APARTMENT
# 6673115                          BOGUS CHECK                       RESIDENCE
# 6673116                            OVER $500                       RESIDENCE
# 6673117  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673118                         RETAIL THEFT                DEPARTMENT STORE
# 6673119                         RETAIL THEFT                DEPARTMENT STORE
# 6673120  FINANCIAL IDENTITY THEFT OVER $ 300             AIRPORT PARKING LOT
# 6673121                       FORCIBLE ENTRY                   CHA APARTMENT
# 6673122       AGGRAVATED:KNIFE/CUTTING INSTR                    CTA BUS STOP
# 6673123                        FROM BUILDING                       APARTMENT
# 6673124        STOLEN PROP: BUY/RECEIVE/POS.                       APARTMENT
# 6673125                          TO PROPERTY                       APARTMENT
# 6673126       HARASSMENT BY ELECTRONIC MEANS                       RESIDENCE
# 6673127              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 6673128                       $500 AND UNDER                       APARTMENT
# 6673129                           AUTOMOBILE   AIRPORT VENDING ESTABLISHMENT
# 6673130             FRAUD OR CONFIDENCE GAME                       RESIDENCE
# 6673131  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673132                               SIMPLE                        SIDEWALK
# 6673133                       $500 AND UNDER                          STREET
# 6673134                       $500 AND UNDER                       RESIDENCE
# 6673135                           AUTOMOBILE           MEDICAL/DENTAL OFFICE
# 6673136                          TO PROPERTY         RESIDENCE PORCH/HALLWAY
# 6673137                       $500 AND UNDER                       RESIDENCE
# 6673138                         RETAIL THEFT              SMALL RETAIL STORE
# 6673139                         RETAIL THEFT                DEPARTMENT STORE
#
#          Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  \
# 0         False     False  1111      11.0  28.0            25.0      04B
# 1          True     False   725       7.0  15.0            67.0       26
# 2         False      True   222       2.0   4.0            39.0      08B
# 3         False     False   225       2.0   3.0            40.0      08B
# 4         False     False  1113      11.0  28.0            25.0       03
# 5         False     False   223       2.0   4.0            39.0      08B
# 6         False      True   733       7.0  17.0            68.0      08B
# 7         False      True   213       2.0   3.0            38.0      08B
# 8          True     False   912       9.0  11.0            59.0       18
# 9         False     False   511       5.0   6.0            49.0      08B
# 10        False     False   533       5.0   9.0            54.0       14
# 11        False      True   623       6.0  17.0            69.0       26
# 12         True     False   423       4.0  10.0            46.0       15
# 13        False     False  1233      12.0   2.0            28.0      08B
# 14         True     False  1531      15.0  37.0            25.0       06
# 15        False     False   421       4.0   7.0            43.0       05
# 16        False     False  1423      14.0   1.0            24.0       07
# 17        False     False   734       7.0  17.0            67.0       06
# 18         True     False   512       5.0  34.0            49.0       24
# 19        False     False   412       4.0   8.0            48.0       06
# 20         True     False   411       4.0   5.0            43.0       06
# 21         True     False   111       1.0  42.0            32.0       12
# 22        False     False  2023      20.0  48.0            77.0       03
# 23        False     False   414       4.0   8.0            43.0      04B
# 24         True     False  1513      15.0  29.0            25.0       15
# 25         True      True  1034      10.0  25.0            31.0      08B
# 26         True      True   232       2.0  20.0            40.0      08B
# 27        False     False  2222      22.0  21.0            73.0      08A
# 28        False     False   621       6.0  17.0            71.0      08B
# 29        False     False   613       6.0  21.0            71.0      04B
# ...         ...       ...   ...       ...   ...             ...      ...
# 6673110   False     False   921       9.0  12.0            58.0       02
# 6673111   False     False  2422      24.0  49.0             1.0       11
# 6673112   False     False   313       3.0  20.0            42.0       05
# 6673113   False     False   533       5.0   9.0            54.0       11
# 6673114   False      True  2525      25.0  31.0            20.0       20
# 6673115   False     False  1723      17.0  33.0            16.0       11
# 6673116   False     False   925       9.0  11.0            61.0       06
# 6673117   False     False   512       5.0   9.0            49.0       11
# 6673118   False     False   622       6.0  21.0            44.0       06
# 6673119   False     False   622       6.0  21.0            44.0       06
# 6673120   False     False   814       8.0  23.0            56.0       11
# 6673121   False     False   634       6.0  21.0            49.0       05
# 6673122   False     False  1232      12.0  25.0            28.0      04B
# 6673123   False     False  2412      24.0  50.0             2.0       06
# 6673124   False     False   931       9.0  20.0            61.0       13
# 6673125   False     False   313       3.0  20.0            42.0       14
# 6673126   False     False  1925      19.0  44.0             6.0       26
# 6673127   False      True   631       6.0   6.0            44.0      08B
# 6673128   False     False   313       3.0  20.0            42.0       06
# 6673129   False     False  1654      16.0  41.0            76.0       07
# 6673130   False     False   511       5.0   9.0            49.0       11
# 6673131   False     False   522       5.0  34.0            53.0       11
# 6673132   False      True   533       5.0   9.0            54.0      08A
# 6673133   False     False  2433      24.0  40.0            77.0       06
GGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET S...
# 9936                        FINAN EXPLOIT-ELDERLY/DISABLED
# 10154                        FINANCIAL ID THEFT: OVER $300
# 10340                                     TELEPHONE THREAT
# 10729                             FRAUD OR CONFIDENCE GAME
# 10843                                        FROM BUILDING
# 10878                                    TO STATE SUP LAND
# 10922                        FINANCIAL ID THEFT: OVER $300
# 11424                                       $500 AND UNDER
# 11633                                     TELEPHONE THREAT
# 11644                        AGG CRIM SEX ABUSE FAM MEMBER
# 11805                                        FROM BUILDING
# 12017                        FINANCIAL ID THEFT: OVER $300
# 12706                                               SIMPLE
# 12877                        FINANCIAL ID THEFT: OVER $300
# 12896                             FRAUD OR CONFIDENCE GAME
# 12985                                OTHER VEHICLE OFFENSE
# 14571                        FINANCIAL ID THEFT: OVER $300
# 14960                          PRO EMP HANDS NO/MIN INJURY
# 15072                                       $500 AND UNDER
# 15187                                              FORGERY
# ...                                                    ...
# 6673110                     AGG SEX ASSLT OF CHILD FAM MBR
# 6673111                FINANCIAL IDENTITY THEFT OVER $ 300
# 6673112                                     FORCIBLE ENTRY
# 6673113                                    INSURANCE FRAUD
# 6673114                      AGG CRIM SEX ABUSE FAM MEMBER
# 6673115                                        BOGUS CHECK
# 6673116                                          OVER $500
# 6673117                FINANCIAL IDENTITY THEFT OVER $ 300
# 6673118                                       RETAIL THEFT
# 6673119                                       RETAIL THEFT
# 6673120                FINANCIAL IDENTITY THEFT OVER $ 300
# 6673121                                     FORCIBLE ENTRY
# 6673122                     AGGRAVATED:KNIFE/CUTTING INSTR
# 6673123                                      FROM BUILDING
# 6673124                      STOLEN PROP: BUY/RECEIVE/POS.
# 6673125                                        TO PROPERTY
# 6673126                     HARASSMENT BY ELECTRONIC MEANS
# 6673127                            DOMESTIC BATTERY SIMPLE
# 6673128                                     $500 AND UNDER
# 6673129                                         AUTOMOBILE
# 6673130                           FRAUD OR CONFIDENCE GAME
# 6673131                FINANCIAL IDENTITY THEFT OVER $ 300
# 6673132                                             SIMPLE
# 6673133                                     $500 AND UNDER
# 6673134                                     $500 AND UNDER
# 6673135                                         AUTOMOBILE
# 6673136                                        TO PROPERTY
# 6673137                                     $500 AND UNDER
# 6673138                                       RETAIL THEFT
# 6673139                                       RETAIL THEFT
#
#                    Location Description  Arrest  Domestic  Beat  District  \
# 1325     PARKING LOT/GARAGE(NON.RESID.)   False     False  2422      24.0
# 4337                          APARTMENT   False     False  2112       2.0
# 4761                          RESIDENCE   False     False  2123       2.0
# 8233                          RESIDENCE   False     False   233       2.0
# 8385                             STREET   False     False   432       4.0
# 8695                        GAS STATION   False     False   814       8.0
# 8805                             STREET   False     False   632       6.0
# 9194                          RESIDENCE   False      True  2515      25.0
# 9350                             STREET   False     False   925       9.0
# 9737                             STREET   False     False   211       2.0
# 9936                              OTHER   False     False   832       8.0
# 10154                         RESIDENCE   False     False  1324      12.0
# 10340                         RESIDENCE   False     False  2311      19.0
# 10729                         RESIDENCE   False     False   832       8.0
# 10843                         RESIDENCE   False     False   411       4.0
# 10878                     CHA APARTMENT   False     False   134       1.0
# 10922                         RESIDENCE   False     False   424       4.0
# 11424                            STREET   False     False  1624      16.0
# 11633                         RESIDENCE   False      True  1223      12.0
# 11644                         RESIDENCE   False      True   324       3.0
# 11805                         RESIDENCE   False      True   531       5.0
# 12017                         RESIDENCE   False     False  1923      19.0
# 6673137   8.0            43.0       06  2018  08/14/2018 04:06:48 PM
# 6673138  13.0            70.0       06  2018  08/14/2018 04:06:48 PM
# 6673139  42.0             8.0       06  2018  08/14/2018 04:06:48 PM
#
#          Latitude  Longitude Hour Month  Day Week Weekday
# 1325          NaN        NaN   14     5  142   21       0
# 4337          NaN        NaN    0     6  166   24       5
# 4761          NaN        NaN    0     7  183   27       3
# 8233          NaN        NaN    0     8  231   33       4
# 8385          NaN        NaN   22     3   64    9       5
# 8695          NaN        NaN    0    12  363   52       3
# 8805          NaN        NaN    9     6  156   23       4
# 9194          NaN        NaN    8     5  146   21       3
# 9350          NaN        NaN   20     5  150   22       1
# 9737          NaN        NaN   19     5  144   21       1
# 9936          NaN        NaN    0     7  182   26       4
# 10154         NaN        NaN    0    10  278   41       0
# 10340         NaN        NaN   12    11  305   44       1
# 10729         NaN        NaN    0    11  305   44       1
# 10843         NaN        NaN    1     9  244   35       3
# 10878         NaN        NaN   22    10  275   39       6
# 10922         NaN        NaN    9    12  335   48       3
# 11424         NaN        NaN   11    12  356   51       3
# 11633         NaN        NaN   15     6  152   22       2
# 11644         NaN        NaN    0    10  302   44       3
# 11805         NaN        NaN    0    10  274   39       5
# 12017         NaN        NaN   12     7  195   28       3
# 12706         NaN        NaN   13    10  296   42       6
# 12877         NaN        NaN    0     8  230   33       6
# 12896         NaN        NaN    9     5  131   19       2
# 12985         NaN        NaN   14    10  288   41       5
# 14571         NaN        NaN    0     8  213   31       0
# 14960         NaN        NaN    8     6  152   22       2
# 15072         NaN        NaN    2    11  305   44       1
# 15187         NaN        NaN    0    12  355   51       2
# ...           ...        ...  ...   ...  ...  ...     ...
# 6673110       NaN        NaN    0     1    1    1       0
# 6673111       NaN        NaN    0     1    1   53       4
# 6673112       NaN        NaN    1     8  216   31       5
# 6673113       NaN        NaN   14     7  207   30       3
# 6673114       NaN        NaN   22     7  195   28       5
# 6673115       NaN        NaN   12     8  216   31       5
# 6673116       NaN        NaN    8     3   79   12       1
# 6673117       NaN        NaN    0     9  249   36       2
# 6673118       NaN        NaN   21     7  212   31       1
# 6673119       NaN        NaN   22     7  209   30       5
# 6673120       NaN        NaN   23     5  137   20       3
# 6673121       NaN        NaN    3     7  211   31       0
# 6673122       NaN        NaN    2     8  218   32       0
# 6673123       NaN        NaN    0     6  164   24       2
# 6673124       NaN        NaN   13     7  212   31       1
# 6673125       NaN        NaN    5     7  211   31       0
# 6673126       NaN        NaN   18     7  212   31       1
# 6673127       NaN        NaN    1     7  187   27       4
# 6673128       NaN        NaN    1     8  214   31       3
# 6673129       NaN        NaN   20     7  194   28       4
# 6673130       NaN        NaN   15     7  196   28       6
# 6673131       NaN        NaN    7     8  217   31       6
# 6673132       NaN        NaN   17     7  211   31       0
# 6673133       NaN        NaN   12     8  219   32       1
# 6673134       NaN        NaN   11     6  173   25       4
# 6673135       NaN        NaN   17     8  215   31       4
# 6673136       NaN        NaN    0     8  213   31       2
# 6673137       NaN        NaN   21     8  214   31       3
# 6673138       NaN        NaN    9     8  217   31       6
# 6673139       NaN        NaN   12     8  219   32       1
#
# [59337 rows x 23 columns]

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6673140 entries, 0 to 6673139
# Data columns (total 23 columns):
# ID                      int64
# Date                    datetime64[ns]
# Block                   object
# IUCR                    object
# Primary Type            category
# Description             category
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Hour                    int64
# Month                   int64
# Day                     int64
# Week                    int64
# Weekday                 int64
# dtypes: bool(2), category(2), datetime64[ns](1), float64(5), int64(8), object(5)
# memory usage: 999.2+ MB

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6673140 entries, 0 to 6673139
# Data columns (total 23 columns):
# ID                      int64
# Date                    datetime64[ns]
# Block                   object
# IUCR                    object
# Primary Type            category
# Description             category
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Hour                    category
# Month                   category
# Day                     category
# Week                    category
# Weekday                 category
# dtypes: bool(2), category(7), datetime64[ns](1), float64(5), int64(3), object(5)
# memory usage: 782.8+ MB

# %%
chi_crimes['Date'].nunique()
# Out:
# 2666199

# %%
chi_crimes['Date'].isnull().sum()
# Out:
# 0

# %%
chi_crimes['Primary Type'].nunique()
# Out:
# 35

# %%
chi_crimes['Primary Type'].unique()
# Out:
# [BATTERY, OTHER OFFENSE, ROBBERY, NARCOTICS, CRIMINAL DAMAGE, ..., NON - CRIMINAL, NON-CRIMINAL, RITUALISM, NON-CRIMINAL (SUBJECT SPECIFIED), DOMESTIC VIOLENCE]
# Length: 35
# Categories (35, object): [BATTERY, OTHER OFFENSE, ROBBERY, NARCOTICS, ..., NON-CRIMINAL, RITUALISM, NON-CRIMINAL (SUBJECT SPECIFIED), DOMESTIC VIOLENCE]

# %%
chi_crimes['Primary Type'].value_counts()
# Out:
# THEFT                                1399665
# BATTERY                              1218668
# CRIMINAL DAMAGE                       763837
# NARCOTICS                             707157
# OTHER OFFENSE                         414072
# ASSAULT                               412902
# BURGLARY                              384632
# MOTOR VEHICLE THEFT                   311497
# DECEPTIVE PRACTICE                    257010
# ROBBERY                               252976
# CRIMINAL TRESPASS                     191547
# WEAPONS VIOLATION                      69137
# PROSTITUTION                           68097
# PUBLIC PEACE VIOLATION                 47418
# OFFENSE INVOLVING CHILDREN             44670
# CRIM SEXUAL ASSAULT                    26565
# SEX OFFENSE                            24699
# INTERFERENCE WITH PUBLIC OFFICER       14791
# GAMBLING                               14362
# LIQUOR LAW VIOLATION                   13986
# ARSON                                  11043
# HOMICIDE                                9256
# KIDNAPPING                              6622
# INTIMIDATION                            3877
# STALKING                                3323
# OBSCENITY                                557
# CONCEALED CARRY LICENSE VIOLATION        229
# PUBLIC INDECENCY                         158
# NON-CRIMINAL                             152
# OTHER NARCOTIC VIOLATION                 123
# HUMAN TRAFFICKING                         42
# NON - CRIMINAL                            38
# RITUALISM                                 23
# NON-CRIMINAL (SUBJECT SPECIFIED)           8
# DOMESTIC VIOLENCE                          1
# Name: Primary Type, dtype: int64

# %%
chi_crimes['Description'].nunique()
# Out:
# 380

# %% [markdown]
# This data set contains data from all crimes reported to the Chicago Police Department from 2001 to 7 days before I downloaded the data. That's a 17 year span of data, and 6,673,139 separate crime reports. From the printouts above, we see there are 35 primary types of crimes, and 380 unique crime descriptions . From the frequency counts, we see that theft, battery, criminal damage, and narcotics are the most common kind of reports.  The IUCR ([Illinois Uniform Crime Reporting](https://data.cityofchicago.org/Public-Safety/Chicago-Police-Department-Illinois-Uniform-Crime-R/c7ck-438e/data)) numbers correspond to a crime description, and per that link, there are 401 codes in use.

# %%
chi_crimes[chi_crimes['Primary Type'] == 'DOMESTIC VIOLENCE']
# Out:
#               ID                Date                Block  IUCR  \
# 1879652  1326195 2001-01-11 02:30:41  087XX S ESCANABA AV  9901
#
#               Primary Type        Description Location Description  Arrest  \
# 1879652  DOMESTIC VIOLENCE  DOMESTIC VIOLENCE            APARTMENT    True
#
#          Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# 1879652      True   423       4.0   NaN             NaN      08B  2001
#
#                      Updated On   Latitude  Longitude
# 1879652  08/17/2015 03:03:40 PM  41.736176  -87.55432

# %% [markdown]
# From the lower end of the frequency counts, I suspect some data may have been entered incorrectly; it's extremely unlikely that there has only been 1 domestic violence report in Chicago over 17 years. The IUCR for this domestic assault entry, 9901, is not included in the IUCR list, so I assume it's simply an entry error. I suspect that this should be Battery, Domestic Battery Simple, and 0486 for Primary, Description, and IUCR.

# %%
chi_crimes.loc[chi_crimes['Primary Type'] == 'DOMESTIC VIOLENCE', 'Primary Type'] = 'BATTERY'
chi_crimes.loc[chi_crimes['Primary Type'] == 'DOMESTIC VIOLENCE', 'Description'] = 'DOMESTIC BATTERY SIMPLE'
chi_crimes.loc[chi_crimes['Primary Type'] == 'DOMESTIC VIOLENCE', 'IUCR'] = '0486'

# %%
crime_counts = chi_crimes['Description'].value_counts()
crime_counts[crime_counts < 20]
# Out:
# REFUSING TO AID AN OFFICER                      19
# JUVENILE PIMPING                                18
# VIOL CHARITABLE GAME ACT                        16
# AIDING ARRESTEE ESCAPE                          15
# $300 AND UNDER                                  15
# BOLITA OR BOLI PUL/WRITER                       14
# FORNICATION                                     13
# OVER $300                                       13
# LOOTING                                         11
# THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN     11
# ARSONIST: ANNUAL REGISTRATION                   11
# BOLITA OR BOLI PUL/OFFICE                        9
# EMPLOY MINOR                                     9
# PATRONIZE JUVENILE PROSTITUTE                    9
# ARMED VIOLENCE                                   9
# FAILURE TO KEEP HYPO RECORDS                     8
# NOTIFICATION OF CIVIL NO CONTACT ORDER           8
# UNLAWFUL USE OF BODY ARMOR                       7
# COMPELLING CONFESSION                            7
# ADULTRY                                          6
# ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN             6
# CALCULATED CANNABIS CONSPIRACY                   6
# NOTIFICATION OF STALKING - NO CONTACT ORDER      6
# CONTRABAND IN PRISON                             6
# ATT AGG CRIM SEXUAL ABUSE                        6
# LOTTERY/PARLAY CARDS                             6
# LOTTERY/OTHER                                    6
# ALTER COINS                                      6
# REGISTER OF SALES BY DEALER                      5
# FAIL REGISTER LIC:CONT SUBS                      5
# AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY      5
# AGG RITUAL MUT:HANDGUN                           5
# AGG RITUAL MUT:OTH DANG WEAPON                   5
# AGG RITUAL MUT:KNIFE/CUTTING I                   5
# CONCEALED CARRY LICENSE REVOCATION               5
# FOUND PASSPORT                                   4
# POLICY/OTHER                                     4
# USE OF METAL PIERCING BULLETS                    4
# ARSONIST: DUTY TO REGISTER                       3
# INVOLUNTARY MANSLAUGHTER                         3
# VIOLATION OF SUMMARY CLOSURE                     3
# ATTEMPT AGG: OTHER FIREARM                       3
# AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY     3
# INTIMIDATION OF LAW ENFORCEMENT OFFICIAL         3
# GUN OFFENDER NOTIFICATION-NO CONTACT             3
# REGISTER FED GAMBLING STAMP                      2
# MARRYING A BIGAMIST                              2
# NATIONAL LOTTERY                                 2
# ARSONIST: FAIL TO REGISTER NEW ADDRESS           2
# THEFT RETAIL                                     1
# DISCLOSE DV VICTIM LOCATION                      1
# KEEP PLACE OF JUV PROSTITUTION                   1
# SPORTS TAMPERING                                 1
# LOTTERY/PARI-MUTUEL                              1
# SECOND DEGREE MURDER                             1
# DOMESTIC VIOLENCE                                1
# Name: Description, dtype: int64

# %%
crime_counts = chi_crimes['Primary Type'].value_counts()
most_frequent_crimes = crime_counts[crime_counts > 20000]
most_frequent_crimes
# Out:
# THEFT                         1399665
# BATTERY                       1218669
# CRIMINAL DAMAGE                763837
# NARCOTICS                      707157
# OTHER OFFENSE                  414072
# ASSAULT                        412902
# BURGLARY                       384632
# MOTOR VEHICLE THEFT            311497
# DECEPTIVE PRACTICE             257010
# ROBBERY                        252976
# CRIMINAL TRESPASS              191547
# WEAPONS VIOLATION               69137
# PROSTITUTION                    68097
# PUBLIC PEACE VIOLATION          47418
# OFFENSE INVOLVING CHILDREN      44670
# CRIM SEXUAL ASSAULT             26565
# SEX OFFENSE                     24699
# Name: Primary Type, dtype: int64

# %%
chi_crimes.loc[chi_crimes['Primary Type'].isin(most_frequent_crimes.index.tolist())]
# Out:
#                ID                Date                                Block  \
# 0        10000092 2015-03-18 19:44:00                      047XX W OHIO ST
# 1        10000094 2015-03-18 23:00:00               066XX S MARSHFIELD AVE
# 2        10000095 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 3        10000096 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 4        10000097 2015-03-18 21:00:00                     047XX W ADAMS ST
# 5        10000098 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 6        10000099 2015-03-18 23:00:00                    070XX S MORGAN ST
# 7        10000100 2015-03-18 21:35:00                  042XX S PRAIRIE AVE
# 8        10000101 2015-03-18 22:09:00                  036XX S WOLCOTT AVE
# 9        10000104 2015-03-18 21:25:00                  097XX S PRAIRIE AVE
# 10       10000105 2015-03-18 21:30:00  130XX S DR MARTIN LUTHER KING JR DR
# 11       10000108 2015-03-15 16:10:00                078XX S VINCENNES AVE
# 12       10000109 2015-03-18 21:14:00                 086XX S EXCHANGE AVE
# 13       10000110 2015-03-18 22:50:00                  014XX S ASHLAND AVE
# 14       10000111 2015-03-18 22:31:00                  051XX W CHICAGO AVE
# 15       10000112 2015-03-18 12:55:00                 077XX S KINGSTON AVE
# 6673138  11413407 2018-08-05 09:57:00                   079XX S CICERO AVE
# 6673139  11413411 2018-08-07 12:31:00                 008XX N MICHIGAN AVE
#
#          IUCR                Primary Type  \
# 0        041A                     BATTERY
# 1        4625               OTHER OFFENSE
# 2        0486                     BATTERY
# 3        0460                     BATTERY
# 4        031A                     ROBBERY
# 5        0460                     BATTERY
# 6        0486                     BATTERY
# 7        0486                     BATTERY
# 8        1811                   NARCOTICS
# 9        0460                     BATTERY
# 10       1320             CRIMINAL DAMAGE
# 11       2825               OTHER OFFENSE
# 12       143A           WEAPONS VIOLATION
# 13       0460                     BATTERY
# 14       0860                       THEFT
# 15       0610                    BURGLARY
# 16       0910         MOTOR VEHICLE THEFT
# 17       0890                       THEFT
# 18       0470      PUBLIC PEACE VIOLATION
# 19       0890                       THEFT
# 20       0860                       THEFT
# 21       1140          DECEPTIVE PRACTICE
# 22       0320                     ROBBERY
# 23       0430                     BATTERY
# 24       141A           WEAPONS VIOLATION
# 25       0486                     BATTERY
# 26       0486                     BATTERY
# 27       0560                     ASSAULT
# 28       0460                     BATTERY
# 29       041A                     BATTERY
# ...       ...                         ...
# 6673110  1754  OFFENSE INVOLVING CHILDREN
# 6673111  1153          DECEPTIVE PRACTICE
# 6673112  0610                    BURGLARY
# 6673113  1135          DECEPTIVE PRACTICE
# 6673114  1752  OFFENSE INVOLVING CHILDREN
# 6673115  1110          DECEPTIVE PRACTICE
# 6673116  0810                       THEFT
# 6673117  1153          DECEPTIVE PRACTICE
# 6673118  0860                       THEFT
# 6673119  0860                       THEFT
# 6673120  1153          DECEPTIVE PRACTICE
# 6673121  0610                    BURGLARY
# 6673122  0420                     BATTERY
# 6673123  0890                       THEFT
# 6673124  1200          DECEPTIVE PRACTICE
# 6673125  1310             CRIMINAL DAMAGE
# 6673126  2826               OTHER OFFENSE
# 6673127  0486                     BATTERY
# 6673128  0820                       THEFT
# 6673129  0910         MOTOR VEHICLE THEFT
# 6673130  1130          DECEPTIVE PRACTICE
# 6673131  1153          DECEPTIVE PRACTICE
# 6673132  0560                     ASSAULT
# 6673133  0820                       THEFT
# 6673134  0820                       THEFT
# 6673135  0910         MOTOR VEHICLE THEFT
# 6673136  1310             CRIMINAL DAMAGE
# 6673137  0820                       THEFT
# 6673138  0860                       THEFT
# 6673139  0860                       THEFT
#
#                                  Description            Location Description  \
# 0                        AGGRAVATED: HANDGUN                          STREET
# 1                           PAROLE VIOLATION                          STREET
# 2                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 3                                     SIMPLE                       APARTMENT
# 4                             ARMED: HANDGUN                        SIDEWALK
# 5                                     SIMPLE                       APARTMENT
# 6                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 7                    DOMESTIC BATTERY SIMPLE                       APARTMENT
# 8               POSS: CANNABIS 30GMS OR LESS                          STREET
# 9                                     SIMPLE         RESIDENCE PORCH/HALLWAY
# 10                                TO VEHICLE  PARKING LOT/GARAGE(NON.RESID.)
# 11                   HARASSMENT BY TELEPHONE     CTA GARAGE / OTHER PROPERTY
# 12                  UNLAWFUL POSS OF HANDGUN          DRIVEWAY - RESIDENTIAL
# 13                                    SIMPLE                        SIDEWALK
# 14                              RETAIL THEFT                     GAS STATION
# 15                            FORCIBLE ENTRY                       APARTMENT
# 16                                AUTOMOBILE                           OTHER
# 17                             FROM BUILDING              GROCERY FOOD STORE
# 18                          RECKLESS CONDUCT                           ALLEY
# 19                             FROM BUILDING                   BAR OR TAVERN
# 20                              RETAIL THEFT              GROCERY FOOD STORE
# 21                              EMBEZZLEMENT                           OTHER
# 22                     STRONGARM - NO WEAPON                           OTHER
# 23             AGGRAVATED: OTHER DANG WEAPON                       APARTMENT
# 24                      UNLAWFUL USE HANDGUN          VEHICLE NON-COMMERCIAL
# 25                   DOMESTIC BATTERY SIMPLE                       APARTMENT
# 26                   DOMESTIC BATTERY SIMPLE                       APARTMENT
# 27                                    SIMPLE                       RESIDENCE
# 28                                    SIMPLE                       APARTMENT
# 29                       AGGRAVATED: HANDGUN         RESIDENCE PORCH/HALLWAY
# ...                                      ...                             ...
# 6673110       AGG SEX ASSLT OF CHILD FAM MBR                       APARTMENT
# 6673111  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673112                       FORCIBLE ENTRY                       RESIDENCE
# 6673113                      INSURANCE FRAUD                       RESIDENCE
# 6673114        AGG CRIM SEX ABUSE FAM MEMBER                       APARTMENT
# 6673115                          BOGUS CHECK                       RESIDENCE
# 6673116                            OVER $500                       RESIDENCE
# 6673117  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673118                         RETAIL THEFT                DEPARTMENT STORE
# 6673119                         RETAIL THEFT                DEPARTMENT STORE
# 6673120  FINANCIAL IDENTITY THEFT OVER $ 300             AIRPORT PARKING LOT
# 6673121                       FORCIBLE ENTRY                   CHA APARTMENT
# 6673122       AGGRAVATED:KNIFE/CUTTING INSTR                    CTA BUS STOP
# 6673123                        FROM BUILDING                       APARTMENT
# 6673124        STOLEN PROP: BUY/RECEIVE/POS.                       APARTMENT
# 6673125                          TO PROPERTY                       APARTMENT
# 6673126       HARASSMENT BY ELECTRONIC MEANS                       RESIDENCE
# 6673127              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 6673128                       $500 AND UNDER                       APARTMENT
# 6673129                           AUTOMOBILE   AIRPORT VENDING ESTABLISHMENT
# 6673130             FRAUD OR CONFIDENCE GAME                       RESIDENCE
# 6673131  FINANCIAL IDENTITY THEFT OVER $ 300                       RESIDENCE
# 6673132                               SIMPLE                        SIDEWALK
# 6673133                       $500 AND UNDER                          STREET
# 6673134                       $500 AND UNDER                       RESIDENCE
# 6673135                           AUTOMOBILE           MEDICAL/DENTAL OFFICE
# 6673136                          TO PROPERTY         RESIDENCE PORCH/HALLWAY
# 6673137                       $500 AND UNDER                       RESIDENCE
# 6673138                         RETAIL THEFT              SMALL RETAIL STORE
# 6673139                         RETAIL THEFT                DEPARTMENT STORE
#
#          Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  \
# 0         False     False  1111      11.0  28.0            25.0      04B
# 1          True     False   725       7.0  15.0            67.0       26
# 2         False      True   222       2.0   4.0            39.0      08B
# 3         False     False   225       2.0   3.0            40.0      08B
# OTHER WEAPONS VIOLATION                             0
# PANDERING                                           0
# INDECENT SOLICITATION/CHILD                         0
# Name: Description, Length: 380, dtype: int64

# %%
chi_crimes[chi_crimes['Description'] == '$500 AND UNDER']

# %%
chi_crimes.pivot_table(index='Description',
                       values='Arrest',
                       columns='Year',
                       fill_value=0,
                       aggfunc='count')

# %%
tmp = chi_crimes[chi_crimes['Description'] == 'DOMESTIC BATTERY SIMPLE'][['Description', 'Date']] 
# tmp['Date'].dt.hour
# tmp.groupby([chi_crimes['Date'].dt.hour, chi_crimes['Date'].dt.day]).agg(['count'])
# desc_tmp = tmp.groupby([pd.Grouper(key='Date', freq='h')]).count().dropna()
# sns.heatmap(desc_tmp)
# desc_tmp.head()
# chi_crimes[chi_crimes['Description'] == 'DOMESTIC BATTERY SIMPLE'].groupby('Date').count()
tmp1 = tmp.groupby('Date').count().resample('h').count()

# %%
chi_crimes.head()
# Out:
#          ID                Date                   Block  IUCR   Primary Type  \
# 0  10000092 2015-03-18 19:44:00         047XX W OHIO ST  041A        BATTERY
# 1  10000094 2015-03-18 23:00:00  066XX S MARSHFIELD AVE  4625  OTHER OFFENSE
# 2  10000095 2015-03-18 22:45:00   044XX S LAKE PARK AVE  0486        BATTERY
# 3  10000096 2015-03-18 22:30:00    051XX S MICHIGAN AVE  0460        BATTERY
# 4  10000097 2015-03-18 21:00:00        047XX W ADAMS ST  031A        ROBBERY
#
#                Description Location Description  Arrest  Domestic  Beat  \
# 0      AGGRAVATED: HANDGUN               STREET   False     False  1111
# 1         PAROLE VIOLATION               STREET    True     False   725
# 2  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True   222
# 3                   SIMPLE            APARTMENT   False     False   225
# 4           ARMED: HANDGUN             SIDEWALK   False     False  1113
#
#    District  Ward  Community Area FBI Code  Year              Updated On  \
# 0      11.0  28.0            25.0      04B  2015  02/10/2018 03:50:01 PM
# 1       7.0  15.0            67.0       26  2015  02/10/2018 03:50:01 PM
# 2       2.0   4.0            39.0      08B  2015  02/10/2018 03:50:01 PM
# 3       2.0   3.0            40.0      08B  2015  02/10/2018 03:50:01 PM
# 4      11.0  28.0            25.0       03  2015  02/10/2018 03:50:01 PM
#
#     Latitude  Longitude
# 0  41.891399 -87.744385
# 1  41.773372 -87.665319
# 2  41.813861 -87.596643
# 3  41.800802 -87.622619
# 4  41.878065 -87.743354

# %%
chi_crimes.head()
# Out:
#          ID                Date                   Block  IUCR   Primary Type  \
# 0  10000092 2015-03-18 19:44:00         047XX W OHIO ST  041A        BATTERY
# 1  10000094 2015-03-18 23:00:00  066XX S MARSHFIELD AVE  4625  OTHER OFFENSE
# 2  10000095 2015-03-18 22:45:00   044XX S LAKE PARK AVE  0486        BATTERY
# 3  10000096 2015-03-18 22:30:00    051XX S MICHIGAN AVE  0460        BATTERY
# 4  10000097 2015-03-18 21:00:00        047XX W ADAMS ST  031A        ROBBERY
#
#                Description Location Description  Arrest  Domestic  Beat  \
# 0      AGGRAVATED: HANDGUN               STREET   False     False  1111
# 1         PAROLE VIOLATION               STREET    True     False   725
# 2  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True   222
# 3                   SIMPLE            APARTMENT   False     False   225
# 4           ARMED: HANDGUN             SIDEWALK   False     False  1113
#
#    District  Ward  Community Area FBI Code  Year              Updated On  \
# 0      11.0  28.0            25.0      04B  2015  02/10/2018 03:50:01 PM
# 1       7.0  15.0            67.0       26  2015  02/10/2018 03:50:01 PM
# 2       2.0   4.0            39.0      08B  2015  02/10/2018 03:50:01 PM
# 3       2.0   3.0            40.0      08B  2015  02/10/2018 03:50:01 PM
# 4      11.0  28.0            25.0       03  2015  02/10/2018 03:50:01 PM
#
#     Latitude  Longitude  Hour  Month  Day  Week  Weekday
# 0  41.891399 -87.744385    19      3   77    12        2
# 1  41.773372 -87.665319    23      3   77    12        2
# 2  41.813861 -87.596643    22      3   77    12        2
# 3  41.800802 -87.622619    22      3   77    12        2
# 4  41.878065 -87.743354    21      3   77    12        2

# %%
tmp = chi_crimes[['Hour', 'Day', 'Month', 'Year', 'Description']]\
            .groupby(['Year', 'Month', 'Day', 'Hour']).count()
tmp.head()
# Out:
#                      Description
# Year Month Day Hour
# 2001 1     1   0             413
#                1              91
#                2              78
#                3              71
#                4              53

# %%
# X and Y labels
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
weeks = np.arange(0,53).tolist()
weekdays = ['Sun', 'Sat', 'Fri', 'Thu', 'Wed', 'Tue', 'Mon']
hours = np.arange(23,-1,-1).tolist()

# %%
# X and Y labels
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
weeks = np.arange(0,53).tolist()
weekdays = ['Sun', 'Sat', 'Fri', 'Thu', 'Wed', 'Tue', 'Mon']
hours = np.arange(23,-1,-1).tolist()

year = 2003
y_ax = 'Hour'
x_ax = 'Month'
x_labs = months
crime_desc = 'DOMESTIC BATTERY SIMPLE'
def plot_crime_freq_heatmap(crime_desc, x_ax, y_ax, x_labs, y_labs, year, df=chi_crimes):
    tmp = df[(df['Description'] == crime_desc) &
                     (df['Year'] == year)][['Description', y_ax, x_ax]] 
    tmp1 = tmp.pivot_table(index=y_ax, columns=x_ax, values='Description', aggfunc=['count'])
    tmp1.sort_index(ascending=False, inplace=True)
    fig, ax = plt.subplots(figsize=(16,9))
    sns.heatmap(tmp1, ax=ax, annot=False, fmt='d')
    ax.xaxis.set_ticklabels(x_labs, fontsize=14)
    ax.yaxis.set_ticklabels(y_labs, fontsize=12, rotation=0)
    ax.set_xlabel(x_ax, fontsize=14)
    ax.set_ylabel(y_ax, fontsize=14)
    ax.set_title('Frequency of crime: "{}" by {} and {} for {}'
                 .format(crime_desc, y_ax, x_ax, year), fontsize=16)
    plt.show()
    
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Week', 'Hour', weeks, hours, 2003)

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Week', 'Weekday', weeks, weekdays, 2009)

# %%
chi_map = folium.Map(location=[41.85, -87.6], zoom_start=11)
chi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tmp = chi_crimes[(chi_crimes['Description'] == 'DOMESTIC BATTERY SIMPLE') &
                 (chi_crimes['Year'] == 2015) ]
display(tmp.head())
tmp.shape
# Out:
#           ID                Date                  Block  IUCR Primary Type  \
# 2   10000095 2015-03-18 22:45:00  044XX S LAKE PARK AVE  0486      BATTERY
# 6   10000099 2015-03-18 23:00:00      070XX S MORGAN ST  0486      BATTERY
# 7   10000100 2015-03-18 21:35:00    042XX S PRAIRIE AVE  0486      BATTERY
# 25  10000124 2015-03-18 23:30:00       024XX S BELL AVE  0486      BATTERY
# 26  10000126 2015-03-18 22:45:00        003XX E 59TH ST  0486      BATTERY
#
#                 Description Location Description  Arrest  Domestic  Beat  \
# 2   DOMESTIC BATTERY SIMPLE            APARTMENT   False      True   222
# 6   DOMESTIC BATTERY SIMPLE            APARTMENT   False      True   733
# 7   DOMESTIC BATTERY SIMPLE            APARTMENT   False      True   213
# 25  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  1034
# 26  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True   232
#
#     District  Ward  Community Area FBI Code  Year              Updated On  \
# 2        2.0   4.0            39.0      08B  2015  02/10/2018 03:50:01 PM
# 6        7.0  17.0            68.0      08B  2015  02/10/2018 03:50:01 PM
# 7        2.0   3.0            38.0      08B  2015  02/10/2018 03:50:01 PM
# 25      10.0  25.0            31.0      08B  2015  02/10/2018 03:50:01 PM
# 26       2.0  20.0            40.0      08B  2015  02/10/2018 03:50:01 PM
#
#      Latitude  Longitude  Hour  Month  Day  Week  Weekday
# 2   41.813861 -87.596643    22      3   77    12        2
# 6   41.766403 -87.649296    23      3   77    12        2
# 7   41.817553 -87.619819    21      3   77    12        2
# 25  41.848024 -87.682091    23      3   77    12        2
# 26  41.787481 -87.618458    22      3   77    12        2
# (24614, 23)

# %%
from folium.plugins import FastMarkerCluster

# %%
tmp['Latitude'].isnull().sum()
# Out:
# 43

# %%
chi_map = folium.Map(location=[41.85, -87.6], zoom_start=11)
chi_map.add_child(FastMarkerCluster(tmp[['Latitude', 'Longitude']].values.tolist()))
chi_map
# # loop through the 100 crimes and add each to the incidents feature group
# for lat, lng, in zip(tmp.Latitude, tmp.Longitude):
#     incidents.add_child(
#         folium.features.CircleMarker(
#             [lat, lng],
#             radius=1, # define how big you want the circle markers to be
#             color='yellow',
#             fill=True,
#             fill_color='blue',
#             fill_opacity=0.6
#         )
#     )

# # add incidents to map
# chi_map.add_child(incidents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-cf6fe66f81b1> in <module>()
#       1 chi_map = folium.Map(location=[41.85, -87.6], zoom_start=11)
# ----> 2 chi_map.add_child(FastMarkerCluster(tmp[['Latitude', 'Longitude']].values.tolist()))
#       3 chi_map
#       4 # # loop through the 100 crimes and add each to the incidents feature group
#       5 # for lat, lng, in zip(tmp.Latitude, tmp.Longitude):
#
# ~\Anaconda3\envs\py36\lib\site-packages\folium\plugins\fast_marker_cluster.py in __init__(self, data, callback)
#      36         super(FastMarkerCluster, self).__init__([])
#      37         self._name = 'FastMarkerCluster'
# ---> 38         self._data = _validate_coordinates(data)
#      39
#      40         if callback is None:
#
# ~\Anaconda3\envs\py36\lib\site-packages\folium\utilities.py in _validate_coordinates(coordinates)
#      46     if _isnan(coordinates):
#      47         raise ValueError('Location values cannot contain NaNs, '
# ---> 48                          'got:\n{!r}'.format(coordinates))
#      49     coordinates = _locations_tolist(coordinates)
#      50     return coordinates
#
# ValueError: Location values cannot contain NaNs, got:
# [[41.81386068, -87.596642837], [41.766402779, -87.649296123], [41.817552577, -87.61981852299999], [41.848024395, -87.68209087700001], [41.787480544, -87.618458018], [41.774499411, -87.60092813600001], [41.752762491, -87.553488733], [41.776797341999995, -87.604098905], [41.767838616999995, -87.59018283200001], [41.884654292, -87.77193778700001], [41.767160003, -87.63512038100001], [41.931993727, -87.71046890299999], [41.754706432, -87.567505523], [41.805166895999996, -87.727180679], [41.748560656, -87.661615335], [41.993281593, -87.709220588], [41.779678598000004, -87.61319547299999], [41.768957248, -
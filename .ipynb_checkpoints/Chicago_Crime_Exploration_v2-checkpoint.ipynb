# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
# %matplotlib inline

# %%
import geopandas as gpd
import geocoder
import folium
import requests
import time
import math
from datetime import datetime

# %%
# Notebook Styling 
# sns.set()
pd.options.display.max_columns = None
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# The data set below is available on this [City of Chicago Data Portal page](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2), but as the file is approximately 1 GB, I've excluded it from this repo.
#
# [Chicago Community Area Geojson](https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Community-Areas-current-/cauq-8yn6)
#
# [Chicago Police Beat Geojson](https://data.cityofchicago.org/Public-Safety/Boundaries-Police-Beats-current-/aerh-rz74)
#
# [Chicago 2010 Census Block Geojson](https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Census-Blocks-2010/mfzt-js4n)

# %%
def process_chicrimes(chi_crimes):
    chi_crimes['Date'] = pd.to_datetime(chi_crimes['Date'], format='%m/%d/%Y %I:%M:%S %p')
    chi_crimes['Updated On'] = pd.to_datetime(chi_crimes['Updated On'], format='%m/%d/%Y %I:%M:%S %p')
    chi_crimes.drop(['Location', 'X Coordinate', 'Y Coordinate'], axis=1, inplace=True)
    chi_crimes['Block'] = chi_crimes['Block'].astype('category')
    chi_crimes['IUCR'] = chi_crimes['IUCR'].astype('category')
    chi_crimes['Primary Type'] = chi_crimes['Primary Type'].astype('category')
    chi_crimes['Description'] = chi_crimes['Description'].astype('category')
    chi_crimes['Location Description'] = chi_crimes['Primary Type'].astype('category')
    chi_crimes['Beat'] = chi_crimes['Beat'].astype(int)
    chi_crimes['District'] = chi_crimes['District'].astype('category')
    chi_crimes['Ward'] = chi_crimes['Ward'].astype('category')
    chi_crimes['Community Area'] = chi_crimes['Community Area'].astype('category')
    chi_crimes['FBI Code'] = chi_crimes['FBI Code'].astype('category')
    chi_crimes['Hour'] = chi_crimes['Date'].dt.hour
    chi_crimes['Week'] = chi_crimes['Date'].dt.weekofyear
    chi_crimes['Day'] = chi_crimes['Date'].dt.dayofyear
    chi_crimes['Weekday'] = chi_crimes['Date'].dt.dayofweek
    chi_crimes['Month'] = chi_crimes['Date'].dt.month
    chi_crimes['Hour'] = chi_crimes['Hour'].astype('category')
    chi_crimes['Week'] = chi_crimes['Week'].astype('category')
    chi_crimes['Day'] = chi_crimes['Day'].astype('category')
    chi_crimes['Weekday'] = chi_crimes['Weekday'].astype('category')
    chi_crimes['Month'] = chi_crimes['Month'].astype('category')
    return chi_crimes

# %%
CSV_PATH = os.path.join('data', 'big', 'Crimes_-_2001_to_present.csv')
crime_dtypes = {'District':str,
                'Ward':str, 
                'Community Area':str}
chi_crimes = pd.read_csv(CSV_PATH, dtype=crime_dtypes, encoding='latin1') 
chi_crimes.head()
# Out:
# C:\Users\mattt\Anaconda3\envs\geo_env\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11034701    JA366925  01/01/2001 11:00:00 AM       016XX E 86TH PL  1153
# 1  11227287    JB147188  10/08/2017 03:00:00 AM    092XX S RACINE AVE  0281
# 2  11227583    JB147595  03/28/2017 02:00:00 PM       026XX W 79TH ST  0620
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  060XX S EBERHART AVE  0810
# 4  11227634    JB147599  08/26/2017 10:00:00 AM   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# 3                THEFT                            OVER $500
# 4  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  Beat District Ward Community Area  \
# 0            RESIDENCE   False     False   412      004    8             45
# 1            RESIDENCE   False     False  2222      022   21             73
# 2                OTHER   False     False   835      008   18             70
# 3            RESIDENCE   False     False   313      003   20             42
# 4          HOTEL/MOTEL   False     False   122      001   42             32
#
#   FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 0       11           NaN           NaN  2001  08/05/2017 03:50:08 PM
# 1       02           NaN           NaN  2017  02/11/2018 03:57:41 PM
# 2       05           NaN           NaN  2017  02/11/2018 03:57:41 PM
# 3       06           NaN           NaN  2017  02/11/2018 03:57:41 PM
# 4       02           NaN           NaN  2017  02/11/2018 03:57:41 PM
#
#    Latitude  Longitude Location  Historical Wards 2003-2015  Zip Codes  \
# 0       NaN        NaN      NaN                         NaN        NaN
# 1       NaN        NaN      NaN                         NaN        NaN
# 2       NaN        NaN      NaN                         NaN        NaN
# 3       NaN        NaN      NaN                         NaN        NaN
# 4       NaN        NaN      NaN                         NaN        NaN
#
#    Community Areas  Census Tracts  Wards  Boundaries - ZIP Codes  \
# 0              NaN            NaN    NaN                     NaN
# 1              NaN            NaN    NaN                     NaN
# 2              NaN            NaN    NaN                     NaN
# 3              NaN            NaN    NaN                     NaN
# 4              NaN            NaN    NaN                     NaN
#
#    Police Districts  Police Beats
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6994576 entries, 0 to 6994575
# Data columns (total 30 columns):
# ID                            int64
# Case Number                   object
# Date                          object
# Block                         object
# IUCR                          object
# Primary Type                  object
# Description                   object
# Location Description          object
# Arrest                        bool
# Domestic                      bool
# Beat                          int64
# District                      object
# Ward                          object
# Community Area                object
# FBI Code                      object
# X Coordinate                  float64
# Y Coordinate                  float64
# Year                          int64
# Updated On                    object
# Latitude                      float64
# Longitude                     float64
# Location                      object
# Historical Wards 2003-2015    float64
# Zip Codes                     float64
# Community Areas               float64
# Census Tracts                 float64
# Wards                         float64
# Boundaries - ZIP Codes        float64
# Police Districts              float64
# Police Beats                  float64
# dtypes: bool(2), float64(12), int64(3), object(13)
# memory usage: 1.5+ GB

# %%
chi_crimes = process_chicrimes(chi_crimes)

# %%
chi_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6994576 entries, 0 to 6994575
# Data columns (total 32 columns):
# ID                            int64
# Case Number                   object
# Date                          datetime64[ns]
# Block                         category
# IUCR                          category
# Primary Type                  category
# Description                   category
# Location Description          category
# Arrest                        bool
# Domestic                      bool
# Beat                          int32
# District                      category
# Ward                          category
# Community Area                category
# FBI Code                      category
# Year                          int64
# Updated On                    datetime64[ns]
# Latitude                      float64
# Longitude                     float64
# Historical Wards 2003-2015    float64
# Zip Codes                     float64
# Community Areas               float64
# Census Tracts                 float64
# Wards                         float64
# Boundaries - ZIP Codes        float64
# Police Districts              float64
# Police Beats                  float64
# Hour                          category
# Week                          category
# Day                           category
# Weekday                       category
# Month                         category
# dtypes: bool(2), category(14), datetime64[ns](2), float64(10), int32(1), int64(2), object(1)
# memory usage: 976.9+ MB

# %%
chi_crimes.head(2)
# Out:
#          ID Case Number                Date               Block  IUCR  \
# 0  11034701    JA366925 2001-01-01 11:00:00     016XX E 86TH PL  1153
# 1  11227287    JB147188 2017-10-08 03:00:00  092XX S RACINE AVE  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  Beat District Ward Community Area  \
# 0   DECEPTIVE PRACTICE   False     False   412      004    8             45
# 1  CRIM SEXUAL ASSAULT   False     False  2222      022   21             73
#
#   FBI Code  Year          Updated On  Latitude  Longitude  \
# 0       11  2001 2017-08-05 15:50:08       NaN        NaN
# 1       02  2017 2018-02-11 15:57:41       NaN        NaN
#
#    Historical Wards 2003-2015  Zip Codes  Community Areas  Census Tracts  \
# 0                         NaN        NaN              NaN            NaN
# 1                         NaN        NaN              NaN            NaN
#
#    Wards  Boundaries - ZIP Codes  Police Districts  Police Beats Hour Week  \
# 0    NaN                     NaN               NaN           NaN   11    1
# 1    NaN                     NaN               NaN           NaN    3   40
#
#    Day Weekday Month
# 0    1       0     1
# 1  281       6    10

# %%
df.head()
# Out:
#           ID Case Number                Date                   Block  IUCR  \
# 28567   2174    HJ374672 2003-05-20 03:15:00      015XX N LASALLE ST  0110
# 36782    983     G446123 2001-07-29 10:15:00      011XX N LASALLE ST  0110
# 60820  24378    JC113580 2019-01-11 22:30:00  000XX E IDA B WELLS DR  0110
# 64270  24561    JC281195 2019-05-27 23:42:00      085XX S CICERO AVE  0110
# 64386  24562    JC281250 2019-05-28 00:25:00  018XX N MONTICELLO AVE  0110
#
#       Primary Type          Description Location Description  Arrest  \
# 28567     HOMICIDE  FIRST DEGREE MURDER             HOMICIDE    True
# 36782     HOMICIDE  FIRST DEGREE MURDER             HOMICIDE    True
# 60820     HOMICIDE  FIRST DEGREE MURDER             HOMICIDE    True
# 64270     HOMICIDE  FIRST DEGREE MURDER             HOMICIDE    True
# 64386     HOMICIDE  FIRST DEGREE MURDER             HOMICIDE   False
#
#        Domestic  Beat District Ward Community Area FBI Code  Year  \
# 28567      True  1821      018  NaN            NaN      01A  2003
# 36782     False  1824      018  NaN            NaN      01A  2001
# 60820     False   111      001    4             32      01A  2019
# 64270     False   834      008   18             70      01A  2019
# 64386     False  2535      025    1             22      01A  2019
#
#                Updated On   Latitude  Longitude  Historical Wards 2003-2015  \
# 28567 2018-05-03 15:49:53        NaN        NaN                         NaN
# 36782 2018-05-03 15:49:53        NaN        NaN                         NaN
# 60820 2019-03-09 15:58:58        NaN        NaN                         NaN
# 64270 2019-07-27 16:05:02  41.737710 -87.740958                         6.0
# 64386 2019-06-04 16:10:41  41.914092 -87.717899                        10.0
#
#        Zip Codes  Community Areas  Census Tracts  Wards  \
# 28567        NaN              NaN            NaN    NaN
# 36782        NaN              NaN            NaN    NaN
# 60820        NaN              NaN            NaN    NaN
# 64270     4300.0             69.0          197.0   30.0
# 64386    22535.0             23.0          388.0   41.0
#
#        Boundaries - ZIP Codes  Police Districts  Police Beats Hour Week  Day  \
# 28567                     NaN               NaN           NaN    3   21  140
# 36782                     NaN               NaN           NaN   10   30  210
# 60820                     NaN               NaN           NaN   22    2   11
# 64270                     8.0              13.0         232.0   23   22  147
# 64386                     1.0               6.0         193.0    0   22  148
#
#       Weekday Month
# 28567       1     5
# 36782       6     7
# 60820       4     1
# 64270       0     5
# 64386       1     5

# %%
df['IUCR'].value_counts()
# Out:
# 0110    9900
# 0142      46
# 0141       3
# 1160       0
# 1130       0
#         ...
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 1531       0
# Name: IUCR, Length: 402, dtype: int64

# %%
def freq_selector(freq):
    freq = freq.lower()
    if freq == 'month':
        return 'M'
    elif freq == 'quarter':
        return 'Q'
    else:
        return 'Y'

# %%
figsize = (14,6)
# df = chi_crimes.loc[(chi_crimes['Primary Type'] == 'HOMICIDE') & (chi_crimes['IUCR'] == '0110')]
crime_type = 'HOMICIDE'
start_date = '2010-01-01'
end_date = 'today'

frequency = 'Month'

df = chi_crimes.loc[(chi_crimes['Primary Type'] == crime_type) & (chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date)]

fig, ax = plt.subplots(sharex=True, figsize=figsize)
count_df = df.groupby([pd.Grouper(key='Date', freq=freq_selector('Month'))]).count()['Case Number']
count_df.plot(ax=ax, kind='line', legend=None, label=f"{crime_type.title()} Cases")
ax.set_ylim([0, 1.1 * count_df.max()])
ax.axvline(x='2014-10-20', label='Laquan McDonald Shooting', linestyle='--', color='red')
ax.legend()
ax.set_ylabel(f"{crime_type.title()} Cases (per {frequency})", fontsize=18)
ax.set_xlabel('Date', fontsize=18)
ax.set_title(f"{crime_type.title()} Cases per {frequency} from {start_date} to {end_date}", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Homicide Cases per Month from 2010-01-01 to today')

# %%
figsize = (14,6)
# df = chi_crimes.loc[(chi_crimes['Primary Type'] == 'HOMICIDE') & (chi_crimes['IUCR'] == '0110')]
crime_type = 'WEAPONS VIOLATION'
crime_descr = 'UNLAWFUL USE HANDGUN'
start_date = '2001-01-01'
end_date = 'today'
lable_descr = crime_descr.title()

frequency = 'Year'

# df = chi_crimes.loc[(chi_crimes['Primary Type'] == crime_type) & (chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date) & (chi_crimes['Arrest'] == True)]
df = chi_crimes.loc[(chi_crimes['Description'] == crime_descr) & (chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date) & (chi_crimes['Arrest'] == True)]

fig, ax = plt.subplots(sharex=True, figsize=figsize)
count_df = df.groupby([pd.Grouper(key='Date', freq=freq_selector(frequency))]).count()['Case Number']
count_df.plot(ax=ax, kind='line', legend=None, label=f"{lable_descr} Cases w/ Arrest")
ax.set_ylabel(f"{lable_descr} Cases \n(per {frequency})", fontsize=18)
ax.set_title(f"{lable_descr} Cases resolved by Arrest per {frequency} from {start_date} to {end_date}", fontsize=18)

ax.set_ylim([0, 1.1 * count_df.max()])
ax.axvline(x='2014-10-20', label='Laquan McDonald Shooting', linestyle='--', color='red')
ax.legend()
ax.set_xlabel('Date', fontsize=18)
# Out:
# Text(0.5, 0, 'Date')

# %%
# df = chi_crimes.loc[(chi_crimes['Primary Type'] == 'HOMICIDE') & (chi_crimes['IUCR'] == '0110')]
crime_type = 'WEAPONS VIOLATION'

def arrest_plot(crime_descr, crime_df=chi_crimes, crime_col='Description', start_date='2001-01-01', 
                end_date='today', frequency='Year', arrest=True, figsize=(14,6)):
    lable_descr = crime_descr.title()
    
    if arrest:
        df = crime_df.loc[(chi_crimes[crime_col] == crime_descr) & (chi_crimes['Date'] >= start_date) & 
                          (chi_crimes['Date'] <= end_date) & (chi_crimes['Arrest'] == True)]
        w_arrest = ' w/ Arrest'
        res_by = ' resolved by Arrest'
        
    else:
        df = crime_df.loc[(chi_crimes[crime_col] == crime_descr) & (chi_crimes['Date'] >= start_date) & 
                          (chi_crimes['Date'] <= end_date)]
        w_arrest = ''
        res_by = ''
    
    fig, ax = plt.subplots(sharex=True, figsize=figsize)
    count_df = df.groupby([pd.Grouper(key='Date', freq=freq_selector(frequency))]).count()['Case Number']
    count_df.plot(ax=ax, kind='line', legend=None, label=f"{lable_descr} Cases{w_arrest}")
    ax.set_ylabel(f"{lable_descr} Cases \n(per {frequency})", fontsize=18)
    ax.set_title(f"{lable_descr} Cases{res_by} per {frequency} from {start_date} to {end_date}", fontsize=18)
    
    ax.set_ylim([0, 1.1 * count_df.max()])
    ax.axvline(x='2014-10-20', label='Laquan McDonald Shooting', linestyle='--', color='red')
    ax.legend()
    ax.set_xlabel('Date', fontsize=18)

# %%
# df = chi_crimes.loc[(chi_crimes['Primary Type'] == 'HOMICIDE') & (chi_crimes['IUCR'] == '0110')]
crime_type = 'WEAPONS VIOLATION'

def arrest_plot(crime_descr, crime_df=chi_crimes, crime_col='Description', start_date='2001-01-01', 
                end_date='today', frequency='Year', arrest=True, figsize=(14,6), more_label=''):
    lable_descr = crime_descr.title()
    
    if isinstance(crime_descr, list):
        df = crime_df.loc[(chi_crimes[crime_col].isin(crime_descr)) & (chi_crimes['Date'] >= start_date) & 
                          (chi_crimes['Date'] <= end_date)]
    else:
        df = crime_df.loc[(chi_crimes[crime_col] == crime_descr) & (chi_crimes['Date'] >= start_date) & 
                          (chi_crimes['Date'] <= end_date)]
    
    fig, ax = plt.subplots(sharex=True, figsize=figsize)
    count_df = df.groupby([pd.Grouper(key='Date', freq=freq_selector(frequency))]).count()['Case Number']
    count_df.plot(ax=ax, kind='line', legend=None, label=f"{lable_descr} Cases", color='#0570b0')
    arr_count_df = df.loc[df['Arrest'] == True].groupby([pd.Grouper(key='Date', freq=freq_selector(frequency))]).count()['Case Number']
    arr_count_df.plot(ax=ax, kind='line', legend=None, label=f"{lable_descr} Cases w/ Arrest", color='#41ae76')
    
    ax.set_ylabel(f"{lable_descr} Cases \n(per {frequency})", fontsize=18)
    ax.set_title(f"{more_label}{lable_descr} Cases per {frequency} from {start_date} to {end_date}", fontsize=18)
    ax.set_xlabel('Date', fontsize=18)
    
    ax.set_ylim([0, 1.1 * max([count_df.max(), arr_count_df.max()])])
    if freq_selector(frequency) == 'Y':
        ax.axvline(x='2015-04-15', label='Laquan McDonald becomes major News', linestyle='--', color='#b30000')
#         ax.axvline(x='2015', label='Laquan McDonald Shooting', linestyle='--', color='#ef6548')
    else:
        ax.axvline(x='2014-11-01', label='Laquan McDonald Shooting', linestyle='--', color='#ef6548')
        ax.axvline(x='2015-04-15', label='Laquan McDonald becomes major News', linestyle='--', color='#b30000')
    ax.legend()

# %% [markdown]
# Looks like there's something about the way pd.Grouper() groups dates that forces vertical date-indicating lines into one of those groups. Maybe there's a nice workaround that I'm not aware of.

# %%
arrest_plot(crime_descr='HOMICIDE', crime_col='Primary Type', frequency='year', start_date='2005')

# %%
arrest_plot(crime_descr='HOMICIDE', crime_col='Primary Type', frequency='Month', start_date='2005')

# %%
arrest_plot(crime_descr='AGGRAVATED: HANDGUN', crime_col='Description', frequency='year', start_date='2005', more_label='Battery, ')

# %%
arrest_plot(crime_descr='AGGRAVATED: HANDGUN', crime_col='Description', frequency='month', start_date='2005', more_label='Battery, ')

# %%
arrest_plot(crime_descr='AGGRAVATED: OTHER DANG WEAPON', crime_col='Description', frequency='month', start_date='2005', more_label='Battery, ')

# %%
arrest_plot(crime_descr='AGGRAVATED: OTHER DANG WEAPON', crime_col='Description', frequency='year', start_date='2005', more_label='Battery, ')

# %%
arrest_plot(crime_descr='UNLAWFUL USE HANDGUN', frequency='Year', start_date='2005')

# %%
arrest_plot(crime_descr='UNLAWFUL USE HANDGUN', frequency='Month', start_date='2005')

# %%
arrest_plot(crime_descr='UNLAWFUL USE OTHER DANG WEAPON', frequency='Year', start_date='2005')

# %%
arrest_plot(crime_descr='UNLAWFUL POSS OF HANDGUN', frequency='Month', start_date='2005')

# %%
arrest_plot(crime_descr='UNLAWFUL POSS OF HANDGUN', frequency='year', start_date='2005')

# %%
arrest_plot(crime_descr='HOMICIDE', frequency='Year', start_date='2005', crime_col='Primary Type')

# %%
figsize = (14,6)
# df = chi_crimes.loc[(chi_crimes['Primary Type'] == 'HOMICIDE') & (chi_crimes['IUCR'] == '0110')]
crime_type = 'WEAPONS VIOLATION'
crime_descr = 'UNLAWFUL POSS OF HANDGUN'
start_date = '2010-01-01'
end_date = 'today'
lable_descr = crime_descr.title()

frequency = 'Month'

# df = chi_crimes.loc[(chi_crimes['Primary Type'] == crime_type) & (chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date)]
df = chi_crimes.loc[(chi_crimes['Description'] == crime_descr) & (chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date)]

fig, ax = plt.subplots(sharex=True, figsize=figsize)
count_df = df.groupby([pd.Grouper(key='Date', freq=freq_selector('Month'))]).count()['Case Number']
count_df.plot(ax=ax, kind='line', legend=None, label=f"{lable_descr} Cases")
ax.set_ylabel(f"{lable_descr} Cases (per {frequency})", fontsize=18)
ax.set_title(f"{lable_descr} Cases per {frequency} from {start_date} to {end_date}", fontsize=18)

ax.set_ylim([0, 1.1 * count_df.max()])
ax.axvline(x='2014-10-20', label='Laquan McDonald Shooting', linestyle='--', color='red')
ax.legend()
ax.set_xlabel('Date', fontsize=18)
# Out:
# Text(0.5, 0, 'Date')

# %%
crime_type.title()
# Out:
# 'Homicide'

# %%
UNLAWFUL POSS OF HANDGUN
# Out:
# Date
# 2001-01-31    42
# 2001-02-28    27
# 2001-03-31    37
# 2001-04-30    59
# 2001-05-31    42
#               ..
# 2019-06-30    52
# 2019-07-31    44
# 2019-08-31    50
# 2019-09-30    49
# 2019-10-31    25
# Freq: M, Name: Case Number, Length: 226, dtype: int64

# %%
chi_crimes.loc[:,'Primary Type'].value_counts()
# Out:
# THEFT                                1427332
# BATTERY                              1238778
# CRIMINAL DAMAGE                       775204
# NARCOTICS                             712700
# ASSAULT                               421167
# OTHER OFFENSE                         420879
# BURGLARY                              389632
# MOTOR VEHICLE THEFT                   315719
# DECEPTIVE PRACTICE                    265288
# ROBBERY                               257023
# CRIMINAL TRESPASS                     194278
# WEAPONS VIOLATION                      71444
# PROSTITUTION                           68418
# PUBLIC PEACE VIOLATION                 47988
# OFFENSE INVOLVING CHILDREN             45677
# CRIM SEXUAL ASSAULT                    27348
# SEX OFFENSE                            25235
# INTERFERENCE WITH PUBLIC OFFICER       15309
# GAMBLING                               14427
# LIQUOR LAW VIOLATION                   14082
# ARSON                                  11202
# HOMICIDE                                9505
# KIDNAPPING                              6690
# INTIMIDATION                            3960
# STALKING                                3404
# OBSCENITY                                589
# CONCEALED CARRY LICENSE VIOLATION        304
# NON-CRIMINAL                             171
# PUBLIC INDECENCY                         164
# OTHER NARCOTIC VIOLATION                 124
# HUMAN TRAFFICKING                         51
# NON - CRIMINAL                            38
# RITUALISM                                 23
# NON-CRIMINAL (SUBJECT SPECIFIED)           9
# DOMESTIC VIOLENCE                          1
# Name: Primary Type, dtype: int64

# %%
query = chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE', 'Description'].value_counts()
query[query > 0]
# Out:
# FIRST DEGREE MURDER         9900
# RECKLESS HOMICIDE             46
# INVOLUNTARY MANSLAUGHTER       3
# Name: Description, dtype: int64

# %%
query = chi_crimes.loc[chi_crimes['Primary Type'] == 'BATTERY', 'Description'].value_counts()
query[query > 0]
# Out:
# DOMESTIC BATTERY SIMPLE                                        539490
# SIMPLE                                                         518239
# AGGRAVATED: OTHER DANG WEAPON                                   69680
# AGGRAVATED: HANDGUN                                             37896
# AGGRAVATED:KNIFE/CUTTING INSTR                                  27719
# AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON                  19348
# PRO EMP HANDS NO/MIN INJURY                                     15816
# AGG PO HANDS NO/MIN INJURY                                      13774
# AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST                 13262
# AGG: HANDS/FIST/FEET NO/MINOR INJURY                             5097
# AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY      4243
# AGGRAVATED OF A SENIOR CITIZEN                                   2465
# AGG: HANDS/FIST/FEET SERIOUS INJURY                              2449
# AGGRAVATED PO: OTHER DANG WEAP                                   1611
# AGGRAVATED DOMESTIC BATTERY                                      1546
# AGG PRO.EMP: OTHER DANG WEAPON                                   1413
# AGGRAVATED: OTHER FIREARM                                        1330
# AGGRAVATED OF A CHILD                                             742
# AGG PRO EMP HANDS SERIOUS INJ                                     495
# AGG PO HANDS ETC SERIOUS INJ                                      479
# AGGRAVATED DOMESTIC BATTERY: HANDGUN                              367
# AGGRAVATED PO: HANDGUN                                            308
# AGGRAVATED PO: KNIFE/CUT INSTR                                    227
# AGG PRO.EMP:KNIFE/CUTTING INST                                    189
# AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM                        137
# AGG PRO.EMP: HANDGUN                                              128
# OF UNBORN CHILD                                                    90
# AGGRAVATED OF A UNBORN CHILD                                       55
# AGG PRO.EMP: OTHER FIREARM                                         29
# AGGRAVATED PO: OTHER FIREARM                                       27
# Name: Description, dtype: int64

# %%
query = chi_crimes.loc[chi_crimes['Primary Type'] == 'WEAPONS VIOLATION', 'Description'].value_counts()
query[query > 0]
# Out:
# UNLAWFUL POSS OF HANDGUN                       50853
# UNLAWFUL USE OTHER DANG WEAPON                  8572
# UNLAWFUL USE HANDGUN                            4007
# RECKLESS FIREARM DISCHARGE                      3015
# UNLAWFUL POSS OTHER FIREARM                     2814
# UNLAWFUL USE/SALE AIR RIFLE                     2452
# POSS FIREARM/AMMO:NO FOID CARD                  2078
# UNLAWFUL POSS AMMUNITION                        1573
# UNLAWFUL USE OTHER FIREARM                       686
# UNLAWFUL SALE HANDGUN                            225
# UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL      153
# UNLAWFUL SALE OTHER FIREARM                       88
# DEFACE IDENT MARKS OF FIREARM                     38
# REGISTER OF SALES BY DEALER                        5
# USE OF METAL PIERCING BULLETS                      4
# Name: Description, dtype: int64

# %%
query = chi_crimes.loc[chi_crimes['Description'] == 'UNLAWFUL POSS OF HANDGUN', 'IUCR'].value_counts()
query[query > 0]
# Out:
# 143A    50853
# Name: IUCR, dtype: int64

# %%
query = chi_crimes.loc[:,'Description'].value_counts()
query[(query > 30000) & (query < np.inf)]
# Out:
# SIMPLE                            800054
# $500 AND UNDER                    550320
# DOMESTIC BATTERY SIMPLE           520593
# TO VEHICLE                        376613
# TO PROPERTY                       356720
# OVER $500                         350604
# POSS: CANNABIS 30GMS OR LESS      276782
# FORCIBLE ENTRY                    263933
# AUTOMOBILE                        247609
# FROM BUILDING                     228517
# RETAIL THEFT                      168796
# TELEPHONE THREAT                  135003
# TO LAND                           120276
# POSS: CRACK                       119291
# UNLAWFUL ENTRY                    103494
# HARASSMENT BY TELEPHONE           100749
# AGGRAVATED: OTHER DANG WEAPON      93641
# POSS: HEROIN(WHITE)                92321
# ARMED: HANDGUN                     91039
# STRONGARM - NO WEAPON              89127
# AGGRAVATED: HANDGUN                84649
# AGGRAVATED:KNIFE/CUTTING INSTR     56917
# CREDIT CARD FRAUD                  53640
# UNLAWFUL POSS OF HANDGUN           47548
# SOLICIT ON PUBLIC WAY              47349
# FINANCIAL ID THEFT: OVER $300      44531
# OTHER VEHICLE OFFENSE              36500
# TO STATE SUP LAND                  36336
# VIOLATE ORDER OF PROTECTION        33754
# CRIMINAL DEFACEMENT                33727
# POCKET-PICKING                     33496
# FRAUD OR CONFIDENCE GAME           32551
# ILLEGAL USE CASH CARD              32153
# THEFT OF LABOR/SERVICES            31319
# Name: Description, dtype: int64

# %%
chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE', 'Description'].unique()
# Out:
# [FIRST DEGREE MURDER, RECKLESS HOMICIDE, INVOLUNTARY MANSLAUGHTER]
# Categories (3, object): [FIRST DEGREE MURDER, RECKLESS HOMICIDE, INVOLUNTARY MANSLAUGHTER]

# %%
def plot_monthly_and_yearly_rates(df, crime, col='Primary Type', max_year=2018, figsize=(12,4)):
    with sns.axes_style("darkgrid"):
        df = df[(df['Year'] <= max_year) & (df[col] == crime)]
        df.set_index('Date', inplace=True)
        
        fig, ax = plt.subplots(sharex=True, figsize=figsize)
        mo_df = df[['ID']].groupby([df.index.year, df.index.month]).count()
        mo_df.plot(ax=ax, kind='line', legend=None)
        ax.set_title('Monthly (top) and Annual (bot) {} in Chicago'.format(crime), fontsize=16)
        ax.set_ylabel('{} per Month'.format(crime), fontsize=14)
        ax.set_xlabel('', fontsize=14)
        ax.set_ylim([0, mo_df['ID'].max() * 1.1])
        plt.tight_layout()
        
        fig, ax = plt.subplots(sharex=True, figsize=(12,4))
        yr_df = df[['ID']].groupby([df.index.year]).count()
        yr_df.plot(ax=ax, legend=None)
        ax.set_ylabel('{} per Year'.format(crime), fontsize=14)
        ax.set_xlabel('Year', fontsize=16)
        ax.set_ylim([0, yr_df['ID'].max() * 1.1])
        plt.tight_layout()

# %%
plot_monthly_and_yearly_rates(chi_crimes, 'HOMICIDE')

# %%
plot_monthly_and_yearly_rates(chi_crimes, 'BATTERY')

# %%
chi_crimes[chi_crimes['Description'] == 'TO VEHICLE'].head(3)
# Out:
#           ID Case Number                Date  \
# 10  10000105    HY189984 2015-03-18 21:30:00
# 77  10000203    HY190151 2015-03-19 01:00:00
# 92  10000241    HY188049 2015-03-15 20:45:00
#
#                                   Block  IUCR     Primary Type Description  \
# 10  130XX S DR MARTIN LUTHER KING JR DR  1320  CRIMINAL DAMAGE  TO VEHICLE
# 77                   020XX N PULASKI RD  1320  CRIMINAL DAMAGE  TO VEHICLE
# 92                  014XX N HARDING AVE  1320  CRIMINAL DAMAGE  TO VEHICLE
#
#    Location Description  Arrest  Domestic  Beat District Ward Community Area  \
# 10      CRIMINAL DAMAGE   False     False   533      005    9             54
# 77      CRIMINAL DAMAGE   False     False  2525      025   30             20
# 92      CRIMINAL DAMAGE   False     False  2535      025   30             23
#
#    FBI Code  Year          Updated On   Latitude  Longitude Hour Week Day  \
# 10       14  2015 2018-02-10 15:50:01  41.658138 -87.613673   21   12  77
# 77       14  2015 2018-02-10 15:50:01  41.918321 -87.726596    1   12  78
# 92       14  2015 2018-02-10 15:50:01  41.906867 -87.725213   20   11  74
#
#    Weekday Month
# 10       2     3
# 77       3     3
# 92       6     3

# %%
def get_timescales(span, x=False):
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    weeks = np.arange(0,53).tolist()
    weekdays = ['Sun', 'Sat', 'Fri', 'Thu', 'Wed', 'Tue', 'Mon']
    hours = np.arange(23,-1,-1).tolist()
    if span == 'Month':
        return (span, months)
    elif span == 'Hour':
        return (span, hours)
    elif span == 'Week':
        return (span, weeks)
    else:
        if x:
            weekdays.reverse()
        return ('Weekday', weekdays)

def plot_crime_freq_heatmap(crime_desc, x_ax, y_ax, year, df=chi_crimes, figsize=(14,6), cmap='YlGn', col='Primary Type'):    
    x_ax, x_labs = get_timescales(x_ax, True)
    y_ax, y_labs = get_timescales(y_ax)
    tmp = df[(df[col] == crime_desc) &
             (df['Year'] == year)][[col, y_ax, x_ax]] 
    tmp1 = tmp.pivot_table(index=y_ax, columns=x_ax, values=col, aggfunc=['count'])
    tmp1.sort_index(ascending=False, inplace=True)
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(tmp1, ax=ax, annot=False, fmt='d', cmap=cmap)
    ax.xaxis.set_ticklabels(x_labs, fontsize=14)
    ax.yaxis.set_ticklabels(y_labs, fontsize=12, rotation=0)
    ax.set_xlabel(x_ax, fontsize=14)
    ax.set_ylabel(y_ax, fontsize=14)
    ax.set_title('Frequency of crime: "{}" by {} and {} for {}'
                 .format(crime_desc, y_ax, x_ax, year), fontsize=16)
    plt.show()

# %%
ZIP_SHP_PATH = os.path.join('zip://', 'data', 'Boundaries - Police Beats (current).zip')
beats = gpd.read_file(ZIP_SHP_PATH)
beats['beat_num'] = beats['beat_num'].astype(int)
# ax = beats.plot(figsize=(10,10))
# ax.grid('off')

# %%
chi_crimes.head(2)
# Out:
#          ID Case Number                Date               Block  IUCR  \
# 0  11034701    JA366925 2001-01-01 11:00:00     016XX E 86TH PL  1153
# 1  11227287    JB147188 2017-10-08 03:00:00  092XX S RACINE AVE  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  Beat District Ward Community Area  \
# 0   DECEPTIVE PRACTICE   False     False   412      004    8             45
# 1  CRIM SEXUAL ASSAULT   False     False  2222      022   21             73
#
#   FBI Code  Year          Updated On  Latitude  Longitude  \
# 0       11  2001 2017-08-05 15:50:08       NaN        NaN
# 1       02  2017 2018-02-11 15:57:41       NaN        NaN
#
#    Historical Wards 2003-2015  Zip Codes  Community Areas  Census Tracts  \
# 0                         NaN        NaN              NaN            NaN
# 1                         NaN        NaN              NaN            NaN
#
#    Wards  Boundaries - ZIP Codes  Police Districts  Police Beats Hour Week  \
# 0    NaN                     NaN               NaN           NaN   11    1
# 1    NaN                     NaN               NaN           NaN    3   40
#
#    Day Weekday Month
# 0    1       0     1
# 1  281       6    10

# %%
query = chi_crimes.loc[chi_crimes['Description'] == ].value_counts()
# Out:
#          ID Case Number                Date               Block  IUCR  \
# 0  11034701    JA366925 2001-01-01 11:00:00     016XX E 86TH PL  1153
# 1  11227287    JB147188 2017-10-08 03:00:00  092XX S RACINE AVE  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  Beat District Ward Community Area  \
# 0   DECEPTIVE PRACTICE   False     False   412      004    8             45
# 1  CRIM SEXUAL ASSAULT   False     False  2222      022   21             73
#
#   FBI Code  Year          Updated On  Latitude  Longitude  \
# 0       11  2001 2017-08-05 15:50:08       NaN        NaN
# 1       02  2017 2018-02-11 15:57:41       NaN        NaN
#
#    Historical Wards 2003-2015  Zip Codes  Community Areas  Census Tracts  \
# 0                         NaN        NaN              NaN            NaN
# 1                         NaN        NaN              NaN            NaN
#
#    Wards  Boundaries - ZIP Codes  Police Districts  Police Beats Hour Week  \
# 0    NaN                     NaN               NaN           NaN   11    1
# 1    NaN                     NaN               NaN           NaN    3   40
#
#    Day Weekday Month
# 0    1       0     1
# 1  281       6    10

# %%
start_date='2001-01-01'
end_date='2019-01-03'
gdf=beats
figsize=(10,10)
my_cmap='YlGn'
feat_descr = 'AGGRAVATED: HANDGUN'
feat = 'Case Number'
crime_col='Primary Type'
prime_type = 'BATTERY'
scale=0.6
tight=True

df = chi_crimes[(chi_crimes['Date'] >= start_date) & (chi_crimes['Date'] <= end_date) & (chi_crimes['Description'] == feat_descr)]
count_df = df.groupby(['Beat', 'Primary Type']).count()[feat].unstack(fill_value=0).stack().reset_index()
count_df.rename({0:'Count'}, axis=1, inplace=True)

vmin = map_df['Count'].min()
vmax = map_df['Count'].max()

map_df = pd.merge(left=gdf, right=count_df.loc[count_df['Primary Type'] == prime_type], right_on='Beat', left_on='beat_num', how='left')
map_df['Count'] = map_df['Count'].fillna(0)
fig, ax = plt.subplots(figsize=figsize)
base = gdf.plot(figsize=figsize, color='white', edgecolor='black', linewidth=2, ax=ax)
map_df.plot(column='Count', ax=base, cmap=my_cmap)
_ = ax.axis('off')
_ = ax.set_title('Counts of {} per police beat\nfrom {} to {}'.format(feat, start_date, end_date),
                 fontdict={'fontsize': '25', 'fontweight':'3'})

sm = plt.cm.ScalarMappable(cmap=my_cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm, shrink=scale)
if tight:
    plt.tight_layout()

# %%
feat_descr = 'AGGRAVATED: HANDGUN'

def map_counts(feat_descr, crime_col='Primary Type', prime_type='BATTERY', df_=chi_crimes, start_date='2001-01-01', 
               end_date='2019-01-03', gdf=beats, figsize=(10,10), my_cmap='YlGn', scale=0.6, tight=True):
    df = df_[(df_['Date'] >= start_date) & (df_['Date'] <= end_date) & (df_['Description'] == feat_descr)]
    count_df = df.groupby(['Beat', 'Primary Type']).count()['Case Number'].unstack(fill_value=0).stack().reset_index()
    count_df.rename({0:'Count'}, axis=1, inplace=True)
    
    map_df = pd.merge(left=gdf, right=count_df.loc[count_df['Primary Type'] == prime_type], right_on='Beat', left_on='beat_num', how='left')
    map_df['Count'] = map_df['Count'].fillna(0)
    vmin = map_df['Count'].min()
    vmax = map_df['Count'].max()
    fig, ax = plt.subplots(figsize=figsize)
    base = gdf.plot(figsize=figsize, color='white', edgecolor='black', linewidth=2, ax=ax)
    map_df.plot(column='Count', ax=base, cmap=my_cmap)
    _ = ax.axis('off')
    _ = ax.set_title(f"{feat_descr} cases per police beat\nfrom {start_date} to {end_date}",
                     fontdict={'fontsize': '25', 'fontweight':'3'})
    
    sm = plt.cm.ScalarMappable(cmap=my_cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm._A = []
    cbar = fig.colorbar(sm, shrink=scale)
    if tight:
        plt.tight_layout()

# %%
map_counts(feat_descr='AGGRAVATED: HANDGUN', start_date='2010-01-01', end_date='2019-01-03', scale=0.65)

# %%
def map_counts(df_, col_val, start_date='2001-01-01', end_date='2019-01-03', gdf=beats, val='Arrest', col='Primary Type', my_cmap='YlGn', scale=0.6, tight=True, figsize=(10,10)):
    df = df_[(df_['Date'] >= start_date) & (df_['Date'] <= end_date)].copy()
    fig, ax = plt.subplots(figsize=figsize)
    counts = df.pivot_table(index='Beat', values=val, columns=col, aggfunc='count', fill_value=0)[[col_val]]
    map_df = pd.merge(left=gdf, right=counts, right_index=True, left_on='beat_num')
    vmin = map_df[col_val].min()
    vmax = map_df[col_val].max()
    
    base = gdf.plot(figsize=figsize, color='white', edgecolor='black', linewidth=2, ax=ax)
    map_df.plot(column=col_val, ax=base, cmap=my_cmap)
    _ = ax.axis('off')
    _ = ax.set_title('Counts of {} per police beat\nfrom {} to {}'.format(col_val, start_date, end_date),
                     fontdict={'fontsize': '25', 'fontweight':'3'})
    
    sm = plt.cm.ScalarMappable(cmap=my_cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm._A = []
    cbar = fig.colorbar(sm, shrink=scale)
    if tight:
        plt.tight_layout()

# %%
map_counts(chi_crimes, crime, '{}-01-01'.format(year_of_interest), '{}-12-31'.format(year_of_interest), scale=0.6, figsize=(10,10))

# %% [markdown]
# ## Crime Description: Domestic Battery Simple

# %% [markdown]
# Looks like there was some issue recording domestic battery crimes near the beginning of this data span.

# %%
plot_monthly_and_yearly_rates(chi_crimes, 'DOMESTIC BATTERY SIMPLE', col='Description')

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Month', 'Weekday', 2015, col='Description')

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Month', 'Hour', 2015, col='Description')

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Week', 'Hour', 2015, figsize=(14,5), col='Description')

# %%
plot_crime_freq_heatmap('DOMESTIC BATTERY SIMPLE', 'Weekday', 'Hour', 2015, figsize=(14,5), col='Description')

# %%
map_counts(chi_crimes, 'DOMESTIC BATTERY SIMPLE', '2015-01-01', '2015-12-31', scale=0.6, figsize=(10,10), col='Description')

# %% [markdown]
# ## Crime Primary Type: Homicide

# %% [markdown]
# Looks like there was some issue recording domestic battery crimes near the beginning of this data span.

# %%
crime = 'HOMICIDE'

# %%
plot_monthly_and_yearly_rates(chi_crimes, crime)

# %%
year_of_interest = 2016

# %%
plot_crime_freq_heatmap(crime, 'Month', 'Weekday', year_of_interest)

# %% [markdown]
# Luckily homicides are sufficiently sparse that the heatmap of homicides by hour and week is splotchy and unpleasant to look at.

# %%
plot_crime_freq_heatmap(crime, 'Week', 'Hour', year_of_interest, figsize=(14,5))

# %%
plot_crime_freq_heatmap(crime, 'Month', 'Hour', year_of_interest, figsize=(8,6))

# %%
plot_crime_freq_heatmap(crime, 'Weekday', 'Hour', year_of_interest, figsize=(8,5))

# %%
map_counts(chi_crimes, crime, '{}-01-01'.format(year_of_interest), '{}-12-31'.format(year_of_interest), scale=0.6, figsize=(10,10))

# %% [markdown]
# ## Crime Primary Type: Narcotics

# %% [markdown]
# Looks like there was some issue recording domestic battery crimes near the beginning of this data span.

# %%
crime = 'NARCOTICS'

# %%
plot_monthly_and_yearly_rates(chi_crimes, crime)

# %% [markdown]
# Considering what we saw in the Homicide exploration, it would make sense that enforcement of narcotics crimes would decrease as officers are pulled off to work homicides.

# %%
year_of_interest = 2016

# %%
plot_crime_freq_heatmap(crime, 'Month', 'Weekday', year_of_interest)

# %%
plot_crime_freq_heatmap(crime, 'Month', 'Hour', year_of_interest)

# %%
plot_crime_freq_heatmap(crime, 'Week', 'Hour', year_of_interest, figsize=(14,5))

# %% [markdown]
# That's interesting. It makes sense that Friday evening would be a prime time for narcotics arrests, but it seems strange that

# %%
plot_crime_freq_heatmap(crime, 'Weekday', 'Hour', year_of_interest, figsize=(14,5))

# %%
map_counts(chi_crimes, crime, '{}-01-01'.format(year_of_interest), '{}-12-31'.format(year_of_interest), scale=0.6, figsize=(10,10))

# %%
plot_crime_freq_heatmap('POSS: CRACK', 'Month', 'Hour', months, hours, 2003)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4045eb8dc89b> in <module>()
# ----> 1 plot_crime_freq_heatmap('POSS: CRACK', 'Month', 'Hour', months, hours, 2003)
#
# NameError: name 'months' is not defined

# %%
plot_crime_freq_heatmap('POSS: CRACK', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Month', 'Hour', months, hours, 2003)

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('TELEPHONE THREAT', 'Week', 'Weekday', weeks, weekdays, 2006, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Month', 'Hour', months, hours, 2010)

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POSS: CANNABIS 30GMS OR LESS', 'Week', 'Weekday', weeks, weekdays, 2010)

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Month', 'Hour', months, hours, 2010)

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Week', 'Hour', weeks, hours, 2009, figsize=(14,5))

# %%
plot_crime_freq_heatmap('POCKET-PICKING', 'Week', 'Weekday', weeks, weekdays, 2010)

# %%
query = chi_crimes['Description'].value_counts()
query[(query > 5000) & (query < 10000)]
# Out:
# ATTEMPT: STRONGARM-NO WEAPON               9888
# FIRST DEGREE MURDER                        9466
# AGGRAVATED VEHICULAR HIJACKING             9464
# CRIMINAL SEXUAL ABUSE                      9109
# OTHER OFFENSE                              9012
# POSSESSION OF DRUG EQUIPMENT               8791
# THEFT OF LOST/MISLAID PROP                 8514
# UNLAWFUL USE OTHER DANG WEAPON             8481
# ATTEMPT: ARMED-HANDGUN                     8311
# FINANCIAL IDENTITY THEFT $300 AND UNDER    7696
# COUNTERFEIT CHECK                          7598
# VEHICLE TITLE/REG OFFENSE                  7563
# OTHER WEAPONS VIOLATION                    7351
# BY FIRE                                    7301
# PUBLIC INDECENCY                           7291
# LICENSE VIOLATION                          6975
# OTHER CRIME AGAINST PERSON                 6955
# ENDANGERING LIFE/HEALTH CHILD              6689
# BOMB THREAT                                6565
# TO STATE SUP PROP                          5763
# RESIST/OBSTRUCT/DISARM OFFICER             5758
# AGG CRIMINAL SEXUAL ABUSE                  5595
# OBSTRUCTING IDENTIFICATION                 5378
# PAROLE VIOLATION                           5263
# HOME INVASION                              5098
# VEHICULAR HIJACKING                        5080
# CYCLE, SCOOTER, BIKE W-VIN                 5043
# Name: Description, dtype: int64

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Month', 'Weekday', months, weekdays, 2016)

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Month', 'Hour', months, hours, 2016)

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Week', 'Hour', weeks, hours, 2016, figsize=(14,5))

# %%
plot_crime_freq_heatmap('FIRST DEGREE MURDER', 'Week', 'Weekday', weeks, weekdays, 2016)

# %%
chi_crimes['Primary Type'].value_counts()

# %%
map_counts(chi_crimes, 'THEFT', '2012-01-01', '2012-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'THEFT', '2001-01-01', '2009-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'CRIM SEXUAL ASSAULT', '2010-01-01', '2018-12-31', scale=0.6, figsize=(10,10))

# %% [markdown]
# That's pretty wild. I'm not sure why the magnificent mile is such an outlier regarding criminal sexual assault. Let's take a closer look.

# %%
map_counts(chi_crimes[chi_crimes['Beat'] == 1834], 'CRIM SEXUAL ASSAULT', gdf=beats[beats['beat_num'] == 1834], 
           start_date='2010-01-01', end_date='2018-12-31', scale=0.2)

# %%
query = chi_crimes.loc[(chi_crimes['Beat'] == 1834) & (chi_crimes['Primary Type'] == 'CRIM SEXUAL ASSAULT'), 'IUCR'].value_counts()
query[query > 0]
# Out:
# 0281    182
# 0265     15
# 0291      7
# 0261      5
# 0264      2
# 0273      2
# 0266      2
# 0263      1
# Name: IUCR, dtype: int64

# %%
chi_crimes[chi_crimes['Primary Type'] == 'CRIM SEXUAL ASSAULT']['IUCR'].value_counts()
# Out:
# 0281    15231
# 0265     4460
# 0266     2709
# 0261     1697
# 0291     1246
# 0263     1049
# 0264      305
# 0275      247
# 0273      172
# 0271      147
# 0274       49
# 0262       33
# 0272        3
# 1153        0
# 1155        0
# 1156        0
# 1160        0
# 1154        0
# 9901        0
# 1152        0
# 1185        0
# 1151        0
# 1150        0
# 1170        0
# 1230        0
# 1195        0
# 1200        0
# 1205        0
# 1206        0
# 1210        0
#         ...
# 2080        0
# 2090        0
# 2091        0
# 2092        0
# 2021        0
# 2019        0
# 1754        0
# 2018        0
# 1755        0
# 1780        0
# 1790        0
# 1791        0
# 1792        0
# 1811        0
# 1812        0
# 1821        0
# 1822        0
# 1840        0
# 1850        0
# 1860        0
# 1900        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# 2014        0
# 2015        0
# 2016        0
# 2017        0
# 0110        0
# Name: IUCR, Length: 401, dtype: int64

# %%
map_counts(chi_crimes, 'NARCOTICS', '2012-01-01', '2014-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'PROSTITUTION', '2012-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'HOMICIDE', '2012-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
map_counts(chi_crimes, 'BATTERY', '2014-01-01', '2015-12-31', scale=0.6, figsize=(10,10))

# %%
fig, ax = plt.subplots(figsize=(12,6))
tmp = chi_crimes.loc[chi_crimes['Primary Type'] == 'HOMICIDE'].copy()
tmp.set_index('Date', inplace=True)
tmp[['ID']].groupby([tmp.index.year]).count().plot(ax=ax, legend=None)
# plt.show()
# tmp.index.year
